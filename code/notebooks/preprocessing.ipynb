# %% [markdown]
# # Data Cleaning and Question/Answer Definition

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Mapping Questions/Answers

# %%
df_fusion = pd.read_csv('../../data/raw/fusion_challenge_datos.csv', delimiter=';')
df_melanoma = pd.read_csv('../../data/raw/base_datos_melanomas.csv', delimiter=';', encoding='utf-8')

# %%
df_fusion

# %%
df_melanoma

# %%
df_melanoma.columns

# %%
# We only need one identifier for the images
df_melanoma.drop(columns=['Nº de imagen', 'Identificador de la lesión'], inplace=True)

# %%
df_melanoma

# %%
# Check for NAs/missing values
df_fusion.isna().sum()

# %%
df_melanoma.isna().sum()

# %% [markdown]
# ## Dataframe translation

# %%
# # Function to translate values from Spanish to English
# def translate_value(val):
#     if isinstance(val, str):
#         translation = Translator(from_lang='es', to_lang='en').translate(val)
#     else:
#         translation = val
#     return translation

# %%
# # Function to translate different categories
# def translate_categories(categories, fromLang = 'es', toLang='en'):
#     translator = Translator(from_lang = fromLang, to_lang = toLang)
#     translations = [translator.translate(category) for category in categories]
#     return dict(zip(categories, translations))

# %%
# # Function to translate column names and values in the entire DataFrame
# def translate_dataframe(df, fromLang = 'es', toLang='en'):

#     # Translate column names
#     df.columns = [Translator(from_lang=fromLang, to_lang = toLang).translate(col) for col in df.columns]

#     translations = {}
#     for col in df.columns:
#         unique_categories = df[col].unique()
#         translations[col] = translate_categories(unique_categories)

#     # Map the translations back to the DataFrame
#     for col in df.columns:
#         df[col] = df[col].map(translations[col]).fillna(df[col])

#     return df

# %%
# df_fusion = translate_dataframe(df_fusion)
# df_fusion

# %%
# df_melanoma.columns = [translate_value(col) for col in df_melanoma.columns]
# df_melanoma.columns

# %%
# df_melanoma = df_melanoma.applymap(translate_value)

# %%
df_melanoma.columns

# %%
melanomaData_map = {

    'Nombre del archivo (.jpg)': {
        'colName': 'File name (.jpg)',
        'values': {}
    },

    'Centro de Procedencia': {
        'colName': 'Center',
        'values': {
            'IMO': 'IMO',
            'CDI': 'CDI',
            'CR': 'CR'
        }
    },
    'Equipo de dermatoscopia': {
        'colName': 'Equipment',
        'values': {
            'Molemax-II': 'Molemax-II',
            'Molemax HD': 'Molemax HD',
            'Fotofinder': 'Fotofinder',
            'Heynedermaphot': 'Heynedermaphot',
            'Dermlite Photo': 'Dermlite Photo',
            'Dermlite DL3': 'Dermlite DL3'
        }
    },
    'Tipo de Luz': {
        'colName': 'Light',
        'values': {
            'Polarizada': 'Polarized',
            'No polarizada': 'Non-polarized'
        }
    },
    'Sexo': {
        'colName': 'Gender',
        'values': {
            'Varón': 'Male',
            'Mujer': 'Female'
        }
    },
    'Edad': {
        'colName': 'Age',
        'values': {}
    },
    'Localización': {
        'colName': 'Location',
        'values': {
            'Cuello': 'Neck',
            'Tronco antero - lateral': 'Anterolateral Trunk',
            'Espalda': 'Back',
            'Miembros superiores': 'Upper limbs',
            'Miembros inferiores': 'Lower limbs'
        }
    },
    'Silueta general de la lesión': {
        'colName': 'General Silhouette',
        'values': {
            'Plana': 'Flat',
            'Aplanada sobreelevada': 'Flattened Elevated',
            'Exofítica': 'Exophytic'
        }
    },
    'Diagnóstico histológico': {
        'colName': 'Histology Diagnostic',
        'values': {
            'Melanoma in situ (MIS)': 'Melanoma in situ (MIS)',
            'Melanoma de extensión superficial (MES)': 'Superficial Spreading Melanoma (SSM)',
            'Melanoma nodular (MN)': 'Nodular Melanoma (NM)',
            'Melanoma sobre nevo congénito (MsNCg)': 'Melanoma on Congenital Nevus (MCN)',
            'Melanoma spitzoide/Nevo de Spitz maligno (MS)': 'Spitzoid Melanoma/Malignant Spitz Nevus (MSN)',
            'Nevo azul maligno (NAM)': 'Malignant Blue Nevus (MBN)',
            'Nevo de Spitz (NS)': 'Spitz Nevus (SN)',
            'Nevo de Reed (NR)': 'Reed Nevus (NR)',
            'Nevo melanocítico displásico (NMD)': 'Dysplastic Melanocytic Nevus (DMN)',
            'Nevo melanocítico lentiginoso (NML)': 'Lentiginous Melanocytic Nevus (LMN)',
            'Nevo melanocítico congénito (NMCg)': 'Congenital Melanocytic Nevus (CMN)',
            'Nevo melanocítico juntural (NMJ)': 'Junctional Melanocytic Nevus (JMN)',
            'Nevo melanocítico compuesto (NMC)': 'Compound Melanocytic Nevus (CMN)',
            'Nevo melanocítico intradérmico (NMI)': 'Intradermal Melanocytic Nevus (IMN)',
            'Nevo azul (NA)': 'Blue Nevus (BN)',
            'Lunar no atípico y estable (L)': 'Non-atypical Stable Mole (M)'
        }
    },
    'Nivel de displasia': {
        'colName': 'Dysplasia',
        'values': {
            'No aplica': 'Not Applicable',
            'No disponible': 'Not Available',
            'Severa': 'Severe'
        }
    },
    'Espesor': {
        'colName': 'Thickness',
        'values': {}
    },
    'Nivel de Clark': {
        'colName': 'Clark Level',
        'values': {
            'I (melanoma in situ)': 'I (melanoma in situ)',
            'II': 'II',
            'III': 'III',
            'IV': 'IV',
            'V': 'V'
        }
    },
    'Impresión diagnóstica': {
        'colName': 'Diagnostic Impression',
        'values': {
            'Melanoma': 'Melanoma',
            'Descartar melanoma': 'Exclude Melanoma',
            'Lunar de Spitz/Reed': 'Spitz/Reed Nevus',
            'Lunar Atípico': 'Atypical Mole',
            'Lunar no atípico': 'Non-atypical Mole'
        }
    },
    'Dificultad diagnóstica': {
        'colName': 'Diagnostic Difficulty',
        'values': {
            'Baja': 'Low',
            'Media': 'Medium',
            'Alta': 'High'
        }
    },
    'Extirpación': {
        'colName': 'Excision',
        'values': {
            'No extirpado': 'Not Excised',
            'Primera consulta': 'First Consultation',
            'Seguimento, sin dermatoscopia previa': 'Follow-up, without previous dermoscopy',
            'Seguimiento con dermatoscopia previa, por cambios': 'Follow-up with previous dermoscopy, due to changes',
            'Seguimiento con dermatoscipa previa, por síntomas': 'Follow-up with previous dermoscopy, due to symptoms'

        }
    },
    'Patrón global': {
        'colName': 'Global Pattern',
        'values': {
            'Reticular difuso': 'Diffuse Reticular',
            'Reticular parcheado': 'Patchy Reticular',
            'Globular': 'Globular',
            'Empedrado': 'Cobblestone',
            'Homogéneo': 'Homogeneous',
            'Mixto (mezcla dos de los anteriores)': 'Mixed (mix of two of the above)',
            'Multicomponente ( mezcla 3 o más anteriores )': 'Multicomponent (mix of 3 or more above)',
            'Indefinido': 'Undefined'
        }
    },
    'Patrón globular periférico': {
        'colName': 'Peripheral Globular Pattern',
        'values': {
            'Ausente': 'Absent',
            'Regular convencional': 'Regular Conventional',
            'Regular en estallido': 'Regular Bursting',
            'Irregular convencional': 'Irregular Conventional',
            'Irregular en estallido': 'Irregular Bursting',
            'Focal convencional': 'Focal Conventional',
            'Focal en estallido': 'Focal Bursting'
        }
    },
    'Simetría': {
        'colName': 'Symmetry',
        'values': {
            'Simétrico': 'Symmetric',
            'Asimétrico en un eje': 'Asymmetric on one axis',
            'Asimétrico en dos ejes': 'Asymmetric on two axes'
        }
    },
    'Retículo pigmentado': {
        'colName': 'Pigmented Reticulum',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Retículo negativo': {
        'colName': 'Negative Reticulum',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Puntos/Glóbulos pequeños': {
        'colName': 'Small Dots/Globules',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Glóbulos grandes/Empedrado': {
        'colName': 'Large Globules/Cobblestone',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Glóbulos periféricos': {
        'colName': 'Peripheral Globules',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Proyecciones periféricas': {
        'colName': 'Peripheral Projections',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Área homogénea sin vasos': {
        'colName': 'Homogeneous Area without Vessels',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Área homogénea con vasos': {
        'colName': 'Homogeneous Area with Vessels',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Área indefinida': {
        'colName': 'Undefined Area',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Regresión gris': {
        'colName': 'Gray Regression',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Regresión blanca': {
        'colName': 'White Regression',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Velo azul blanquecino': {
        'colName': 'Whitish Blue Veil',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Crisálidas': {
        'colName': 'Chrysalis',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    }
}

# %%
# Create a copy of the dataframe
df_melanoma_mapped = df_melanoma.copy()

# Columns to map
columns_to_map = df_melanoma.columns

# Iterate through all the columns
for col in columns_to_map:

    # Apply the mapping for the variable name using the dictionary
    newColName = melanomaData_map[col]['colName']

    # Clean all trailing blank spaces from strings before mapping
    # Example: '  Lunar no atípico y estable (L)   ' -> 'Lunar no atípico y estable (L)'
    if df_melanoma_mapped[col].dtype == 'O':
        df_melanoma_mapped[col] = df_melanoma_mapped[col].str.strip()

    # Avoid NaN generation for numerical variables or IDs without translation
    if melanomaData_map[col]['values']:
        df_melanoma_mapped[newColName] = df_melanoma_mapped[col].map(melanomaData_map[col]['values'])
    else:
        df_melanoma_mapped[newColName] = df_melanoma[col]

    # Drop the columns in Spanish
    df_melanoma_mapped.drop(columns=col, inplace=True)

# %%
df_melanoma_mapped.columns

# %%
na_sum = df_melanoma_mapped.isna().sum()
na_sum

# %%
# Store those columns with NAs
columns_with_na = na_sum[na_sum > 0].index.to_list()
columns_with_na

# %%
# Compare the amount of NAs in those columns to check if there has been NA injection
na_sum_original_melanoma = df_melanoma.isna().sum().values
na_sum_mapped_melanoma = df_melanoma_mapped.isna().sum().values

# %%
na_sum_comparison = pd.DataFrame([na_sum_original_melanoma, na_sum_mapped_melanoma], index=['df_melanoma', 'df_melanoma_mapped']).T
na_sum_comparison.index = df_melanoma_mapped.columns

# %%
na_sum_comparison

# %%
excision_missing_index = df_melanoma_mapped[df_melanoma_mapped['Excision'].isna()].index
global_pattern_missing_index = df_melanoma_mapped[df_melanoma_mapped['Global Pattern'].isna()].index

# %%
df_melanoma["Extirpación"][excision_missing_index]

# %%
df_melanoma["Patrón global"][global_pattern_missing_index]

# %%
df_melanoma_mapped

# %%
df_melanoma_mapped.drop(columns={'Thickness', 'Clark Level'}, inplace=True)

# %%
df_melanoma_mapped.columns

# %%
diagnostic_variables = ['General Silhouette', 'Histology Diagnostic', 'Dysplasia', 'Diagnostic Impression',
             'Diagnostic Difficulty', 'Excision', 'Global Pattern', 'Peripheral Globular Pattern',
             'Symmetry', 'Pigmented Reticulum', 'Negative Reticulum', 'Small Dots/Globules',
             'Large Globules/Cobblestone', 'Peripheral Globules', 'Peripheral Projections',
             'Homogeneous Area without Vessels', 'Homogeneous Area with Vessels', 'Undefined Area',
             'Gray Regression', 'White Regression', 'Whitish Blue Veil', 'Chrysalis']

variable_values = {}
for variable in diagnostic_variables:
    variable_values[variable] = df_melanoma_mapped[variable].unique().tolist()

# %%
variable_values

# %%
df_melanoma_mapped.to_csv('../../data/processed/df_melanoma_clean.csv', index=False)

# %%
fusionData_map = {

    'Nombre del archivo (.jpg)': {
        'colName': 'File name (.jpg)',
        'values': {}
    },
    
    'Patrón global': {
        'colName': 'Global Pattern',
        'values': {
            'Reticular difuso': 'Diffuse Reticular',
            'Reticular parcheado': 'Patchy Reticular',
            'Globular': 'Globular',
            'Empedrado': 'Cobblestone',
            'Homogéneo': 'Homogeneous',
            'Mixto (mezcla dos de los anteriores)': 'Mixed (mix of two of the above)',
            'Multicomponente ( mezcla 3 o más anteriores )': 'Multicomponent (mix of 3 or more above)',
            'Indefinido': 'Undefined'
        }
    },

    'Retículo pigmentado': {
        'colName': 'Pigmented Reticulum',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Retículo negativo': {
        'colName': 'Negative Reticulum',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Puntos/Glóbulos pequeños': {
        'colName': 'Small Dots/Globules',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Glóbulos grandes/Empedrado': {
        'colName': 'Large Globules/Cobblestone',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Glóbulos periféricos': {
        'colName': 'Peripheral Globules',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Proyecciones periféricas': {
        'colName': 'Peripheral Projections',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Área homogénea sin vasos': {
        'colName': 'Homogeneous Area without Vessels',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Área homogénea con vasos': {
        'colName': 'Homogeneous Area with Vessels',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Área indefinida': {
        'colName': 'Undefined Area',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Regresión gris': {
        'colName': 'Gray Regression',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Regresión blanca': {
        'colName': 'White Regression',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Velo azul blanquecino': {
        'colName': 'Whitish Blue Veil',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Crisálidas': {
        'colName': 'Chrysalis',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Etiqueta binaria': {
        'colName': 'Binary label',
        'values': {}
    }
}

# %%
# Create a copy of the dataframe
df_fusion_mapped = df_fusion.copy()

# Columns to map
columns_to_map = df_fusion.columns

# Iterate through all the columns
for col in columns_to_map:

    # Apply the mapping for the variable name using the dictionary
    newColName = fusionData_map[col]['colName']

    # Clean all trailing blank spaces from strings before mapping
    # Example: '  Lunar no atípico y estable (L)   ' -> 'Lunar no atípico y estable (L)'
    if df_fusion_mapped[col].dtype == 'O':
        df_fusion_mapped[col] = df_fusion_mapped[col].str.strip()

    # Avoid NaN generation for numerical variables or IDs without translation
    if fusionData_map[col]['values']:
        df_fusion_mapped[newColName] = df_fusion_mapped[col].map(fusionData_map[col]['values'])
    else:
        df_fusion_mapped[newColName] = df_fusion_mapped[col]

    # Drop the columns in Spanish
    df_fusion_mapped.drop(columns=col, inplace=True)

# %%
df_fusion_mapped.columns
# Out:
# Index(['File name (.jpg)', 'Global Pattern', 'Pigmented Reticulum',
#        'Negative Reticulum', 'Small Dots/Globules',
#        'Large Globules/Cobblestone', 'Peripheral Globules',
#        'Peripheral Projections', 'Homogeneous Area without Vessels',
#        'Homogeneous Area with Vessels', 'Undefined Area', 'Gray Regression',
#        'White Regression', 'Whitish Blue Veil', 'Chrysalis', 'Binary label'],
#       dtype='object')

# %%
na_sum = df_fusion_mapped.isna().sum()
na_sum
# Out:
# File name (.jpg)                    0
# Global Pattern                      0
# Pigmented Reticulum                 0
# Negative Reticulum                  0
# Small Dots/Globules                 0
# Large Globules/Cobblestone          0
# Peripheral Globules                 0
# Peripheral Projections              0
# Homogeneous Area without Vessels    0
# Homogeneous Area with Vessels       0
# Undefined Area                      0
# Gray Regression                     0
# White Regression                    0
# Whitish Blue Veil                   0
# Chrysalis                           0
# Binary label                        0
# dtype: int64

# %%
# Compare the amount of NAs in those columns to check if there has been NA injection
na_sum_original_fusion = df_fusion.isna().sum().values
na_sum_mapped_fusion = df_fusion_mapped.isna().sum().values
na_sum_comparison = pd.DataFrame([na_sum_original_fusion, na_sum_mapped_fusion], index=['df_fusion', 'df_fusion_mapped']).T
na_sum_comparison.index = df_fusion_mapped.columns
na_sum_comparison
# Out:
#                                   df_fusion  df_fusion_mapped
# File name (.jpg)                          0                 0
# Global Pattern                            0                 0
# Pigmented Reticulum                       0                 0
# Negative Reticulum                        0                 0
# Small Dots/Globules                       0                 0
# Large Globules/Cobblestone                0                 0
# Peripheral Globules                       0                 0
# Peripheral Projections                    0                 0
# Homogeneous Area without Vessels          0                 0
# Homogeneous Area with Vessels             0                 0
# Undefined Area                            0                 0
# Gray Regression                           0                 0
# White Regression                          0                 0
# Whitish Blue Veil                         0                 0
# Chrysalis                                 0                 0
# Binary label                              0                 0

# %%
diagnostic_variables = ['Global Pattern', 'Pigmented Reticulum', 'Negative Reticulum', 'Small Dots/Globules',
             'Large Globules/Cobblestone', 'Peripheral Globules', 'Peripheral Projections',
             'Homogeneous Area without Vessels', 'Homogeneous Area with Vessels', 'Undefined Area',
             'Gray Regression', 'White Regression', 'Whitish Blue Veil', 'Chrysalis', 'Binary label']

variable_values = {}
for variable in diagnostic_variables:
    variable_values[variable] = df_fusion_mapped[variable].unique().tolist()
    print(variable_values[variable])
# Out:
# ['Diffuse Reticular', 'Mixed (mix of two of the above)', 'Multicomponent (mix of 3 or more above)', 'Patchy Reticular', 'Globular', 'Homogeneous', 'Undefined', 'Cobblestone']
# ['Yes, clear and dominant', 'Yes, subtle', 'No', 'Yes, clear']
# ['No', 'Yes, subtle', 'Yes, clear and dominant', 'Yes, clear']
# ['Yes, subtle', 'No', 'Yes, clear', 'Yes, clear and dominant']
# ['No', 'Yes, clear and dominant', 'Yes, subtle', 'Yes, clear']
# ['No', 'Yes, clear', 'Yes, subtle', 'Yes, clear and dominant']
# ['Yes, subtle', 'No', 'Yes, clear', 'Yes, clear and dominant']
# ['No', 'Yes, subtle', 'Yes, clear and dominant', 'Yes, clear']
# ['No', 'Yes, clear and dominant', 'Yes, clear', 'Yes, subtle']
# ['Yes, subtle', 'No', 'Yes, clear', 'Yes, clear and dominant']
# ['No', 'Yes, subtle', 'Yes, clear']
# ['No', 'Yes, clear', 'Yes, subtle']
# ['No', 'Yes, subtle', 'Yes, clear']
# ['No', 'Yes, clear', 'Yes, subtle']
# ['benign', 'malignant']

# %%
variable_values
# Out:
# {'Global Pattern': ['Diffuse Reticular',
#   'Mixed (mix of two of the above)',
#   'Multicomponent (mix of 3 or more above)',
#   'Patchy Reticular',
#   'Globular',
#   'Homogeneous',
#   'Undefined',
#   'Cobblestone'],
#  'Pigmented Reticulum': ['Yes, clear and dominant',
#   'Yes, subtle',
#   'No',
#   'Yes, clear'],
#  'Negative Reticulum': ['No',
#   'Yes, subtle',
#   'Yes, clear and dominant',
#   'Yes, clear'],
#  'Small Dots/Globules': ['Yes, subtle',
#   'No',
#   'Yes, clear',
#   'Yes, clear and dominant'],
#  'Large Globules/Cobblestone': ['No',
#   'Yes, clear and dominant',
#   'Yes, subtle',
#   'Yes, clear'],
#  'Peripheral Globules': ['No',
#   'Yes, clear',
#   'Yes, subtle',
#   'Yes, clear and dominant'],
#  'Peripheral Projections': ['Yes, subtle',
#   'No',
#   'Yes, clear',
#   'Yes, clear and dominant'],
#  'Homogeneous Area without Vessels': ['No',
#   'Yes, subtle',
#   'Yes, clear and dominant',
#   'Yes, clear'],
#  'Homogeneous Area with Vessels': ['No',
#   'Yes, clear and dominant',
#   'Yes, clear',
#   'Yes, subtle'],
#  'Undefined Area': ['Yes, subtle',
#   'No',
#   'Yes, clear',
#   'Yes, clear and dominant'],
#  'Gray Regression': ['No', 'Yes, subtle', 'Yes, clear'],
#  'White Regression': ['No', 'Yes, clear', 'Yes, subtle'],
#  'Whitish Blue Veil': ['No', 'Yes, subtle', 'Yes, clear'],
#  'Chrysalis': ['No', 'Yes, clear', 'Yes, subtle'],
#  'Binary label': ['benign', 'malignant']}

# %%
df_fusion_mapped[:20]
# Out:
#    File name (.jpg)                           Global Pattern  \
# 0      ISIC_0000000                        Diffuse Reticular
# 1      ISIC_0000001                        Diffuse Reticular
# 2      ISIC_0000002          Mixed (mix of two of the above)
# 3      ISIC_0000004  Multicomponent (mix of 3 or more above)
# 4      ISIC_0000006                         Patchy Reticular
# 5      ISIC_0000007                        Diffuse Reticular
# 6      ISIC_0000008                                 Globular
# 7      ISIC_0000009                                 Globular
# 8      ISIC_0000010          Mixed (mix of two of the above)
# 9      ISIC_0000011                              Homogeneous
# 10     ISIC_0000016                        Diffuse Reticular
# 11     ISIC_0000017          Mixed (mix of two of the above)
# 12     ISIC_0000018                        Diffuse Reticular
# 13     ISIC_0000019                        Diffuse Reticular
# 14     ISIC_0000021                        Diffuse Reticular
# 15     ISIC_0000024          Mixed (mix of two of the above)
# 16     ISIC_0000025                        Diffuse Reticular
# 17     ISIC_0000026  Multicomponent (mix of 3 or more above)
# 18     ISIC_0000028                        Diffuse Reticular
# 19     ISIC_0000029          Mixed (mix of two of the above)
#
#         Pigmented Reticulum       Negative Reticulum      Small Dots/Globules  \
# 0   Yes, clear and dominant                       No              Yes, subtle
# 1   Yes, clear and dominant                       No              Yes, subtle
# 2   Yes, clear and dominant                       No                       No
# 3               Yes, subtle                       No                       No
# 4   Yes, clear and dominant                       No                       No
# 5   Yes, clear and dominant              Yes, subtle                       No
# 6                        No                       No                       No
# 7               Yes, subtle                       No                       No
# 8   Yes, clear and dominant                       No                       No
# 9               Yes, subtle                       No                       No
# 10  Yes, clear and dominant                       No                       No
# 11  Yes, clear and dominant                       No                       No
# 12  Yes, clear and dominant                       No              Yes, subtle
# 13  Yes, clear and dominant                       No                       No
# 14  Yes, clear and dominant                       No               Yes, clear
# 15                       No  Yes, clear and dominant  Yes, clear and dominant
# 16  Yes, clear and dominant                       No                       No
# 17              Yes, subtle                       No               Yes, clear
# 18  Yes, clear and dominant                       No                       No
# 19  Yes, clear and dominant                       No              Yes, subtle
#
#    Large Globules/Cobblestone Peripheral Globules Peripheral Projections  \
# 0                          No                  No            Yes, subtle
# 1                          No                  No                     No
# 2                          No                  No                     No
# 3                          No                  No                     No
# 4                          No                  No                     No
# 5                          No                  No                     No
# 6     Yes, clear and dominant          Yes, clear                     No
# 7     Yes, clear and dominant                  No                     No
# 8                          No                  No                     No
# 9                          No                  No                     No
# 10                         No                  No                     No
# 11    Yes, clear and dominant         Yes, subtle                     No
# 12                         No                  No                     No
# 13                         No                  No                     No
# 14                         No                  No                     No
# 15                Yes, subtle                  No                     No
# 16                         No                  No                     No
# 17                         No                  No                     No
# 18                         No                  No                     No
# 19                         No                  No             Yes, clear
#
#    Homogeneous Area without Vessels Homogeneous Area with Vessels  \
# 0                                No                            No
# 1                       Yes, subtle                            No
# 2           Yes, clear and dominant                            No
# 3           Yes, clear and dominant       Yes, clear and dominant
# 4                                No                            No
# 5                                No                            No
# 6                        Yes, clear                            No
# 7                                No                            No
# 8           Yes, clear and dominant                            No
# 9           Yes, clear and dominant                            No
# 10                               No                            No
# 11                               No                            No
# 12                      Yes, subtle                            No
# 13                               No                            No
# 14                               No                            No
# 15                               No                            No
# 16                               No                    Yes, clear
# 17          Yes, clear and dominant       Yes, clear and dominant
# 18                      Yes, subtle                            No
# 19                       Yes, clear                            No
#
#              Undefined Area Gray Regression White Regression  \
# 0               Yes, subtle              No               No
# 1                        No              No               No
# 2                Yes, clear     Yes, subtle               No
# 3   Yes, clear and dominant      Yes, clear       Yes, clear
# 4                        No              No               No
# 5                        No              No               No
# 6                        No              No               No
# 7                        No              No               No
# 8                        No              No               No
# 9                        No              No               No
# 10                       No              No               No
# 11                       No              No               No
# 12                       No      Yes, clear               No
# 13                       No              No               No
# 14              Yes, subtle              No      Yes, subtle
# 15               Yes, clear              No       Yes, clear
# 16                       No              No               No
# 17               Yes, clear              No       Yes, clear
# 18                       No              No               No
# 19  Yes, clear and dominant      Yes, clear               No
#
#    Whitish Blue Veil Chrysalis Binary label
# 0                 No        No       benign
# 1                 No        No       benign
# 2                 No        No    malignant
# 3        Yes, subtle        No    malignant
# 4                 No        No       benign
# 5                 No        No       benign
# 6                 No        No       benign
# 7                 No        No       benign
# 8                 No        No       benign
# 9                 No        No       benign
# 10                No        No       benign
# 11                No        No       benign
# 12                No        No       benign
# 13                No        No       benign
# 14                No        No       benign
# 15                No        No       benign
# 16                No        No       benign
# 17                No        No    malignant
# 18                No        No       benign
# 19                No        No    malignant

# %%
# Extract the numerical part of the "File name (.jpg)" column and convert it to integer
df_fusion_mapped["Numeric ID"] = df_fusion_mapped["File name (.jpg)"].str.split("_").str[1].astype(int)

# Sort the DataFrame based on the "Numeric ID" column
df_fusion_mapped_sorted = df_fusion_mapped.sort_values(by="Numeric ID")

# Reset the index after sorting
df_fusion_mapped_sorted = df_fusion_mapped_sorted.reset_index(drop=True)

# Drop the temporary "Numeric ID" column if needed
df_fusion_mapped_sorted.drop(columns=["Numeric ID"], inplace=True)

# %%
df_fusion_mapped_sorted[:50]
# Out:
#    File name (.jpg)                           Global Pattern  \
# 0      ISIC_0000000                        Diffuse Reticular
# 1      ISIC_0000001                        Diffuse Reticular
# 2      ISIC_0000002          Mixed (mix of two of the above)
# 3      ISIC_0000004  Multicomponent (mix of 3 or more above)
# 4      ISIC_0000006                         Patchy Reticular
# 5      ISIC_0000007                        Diffuse Reticular
# 6      ISIC_0000008                                 Globular
# 7      ISIC_0000009                                 Globular
# 8      ISIC_0000010          Mixed (mix of two of the above)
# 9      ISIC_0000011                              Homogeneous
# 10     ISIC_0000016                        Diffuse Reticular
# 11     ISIC_0000017          Mixed (mix of two of the above)
# 12     ISIC_0000018                        Diffuse Reticular
# 13     ISIC_0000019                        Diffuse Reticular
# 14     ISIC_0000021                        Diffuse Reticular
# 15     ISIC_0000024          Mixed (mix of two of the above)
# 16     ISIC_0000025                        Diffuse Reticular
# 17     ISIC_0000026  Multicomponent (mix of 3 or more above)
# 18     ISIC_0000028                        Diffuse Reticular
# 19     ISIC_0000029          Mixed (mix of two of the above)
# 20     ISIC_0000030                                Undefined
# 21     ISIC_0000031  Multicomponent (mix of 3 or more above)
# 22     ISIC_0000032          Mixed (mix of two of the above)
# 23     ISIC_0000034                        Diffuse Reticular
# 24     ISIC_0000035          Mixed (mix of two of the above)
# 25     ISIC_0000038                        Diffuse Reticular
# 26     ISIC_0000039          Mixed (mix of two of the above)
# 27     ISIC_0000041                              Homogeneous
# 28     ISIC_0000042          Mixed (mix of two of the above)
# 29     ISIC_0000044                        Diffuse Reticular
# 30     ISIC_0000045          Mixed (mix of two of the above)
# 31     ISIC_0000046                        Diffuse Reticular
# 32     ISIC_0000047                        Diffuse Reticular
# 33     ISIC_0000048          Mixed (mix of two of the above)
# 34     ISIC_0000049                         Patchy Reticular
# 35     ISIC_0000050          Mixed (mix of two of the above)
# 36     ISIC_0000051                        Diffuse Reticular
# 37     ISIC_0000054                        Diffuse Reticular
# 38     ISIC_0000055                        Diffuse Reticular
# 39     ISIC_0000058                              Homogeneous
# 40     ISIC_0000059                        Diffuse Reticular
# 41     ISIC_0000060                        Diffuse Reticular
# 42     ISIC_0000061          Mixed (mix of two of the above)
# 43     ISIC_0000062                        Diffuse Reticular
# 44     ISIC_0000063          Mixed (mix of two of the above)
# 45     ISIC_0000065                        Diffuse Reticular
# 46     ISIC_0000067                        Diffuse Reticular
# 47     ISIC_0000068                        Diffuse Reticular
# 48     ISIC_0000073                              Homogeneous
# 49     ISIC_0000074          Mixed (mix of two of the above)
#
#         Pigmented Reticulum       Negative Reticulum      Small Dots/Globules  \
# 0   Yes, clear and dominant                       No              Yes, subtle
# 1   Yes, clear and dominant                       No              Yes, subtle
# 2   Yes, clear and dominant                       No                       No
# 3               Yes, subtle                       No                       No
# 4   Yes, clear and dominant                       No                       No
# 5   Yes, clear and dominant              Yes, subtle                       No
# 6                        No                       No                       No
# 7               Yes, subtle                       No                       No
# 8   Yes, clear and dominant                       No                       No
# 9               Yes, subtle                       No                       No
# 10  Yes, clear and dominant                       No                       No
# 11  Yes, clear and dominant                       No                       No
# 12  Yes, clear and dominant                       No              Yes, subtle
# 13  Yes, clear and dominant                       No                       No
# 14  Yes, clear and dominant                       No               Yes, clear
# 15                       No  Yes, clear and dominant  Yes, clear and dominant
# 16  Yes, clear and dominant                       No                       No
# 17              Yes, subtle                       No               Yes, clear
# 18  Yes, clear and dominant                       No                       No
# 19  Yes, clear and dominant                       No              Yes, subtle
# 20                       No                       No                       No
# 21  Yes, clear and dominant                       No              Yes, subtle
# 22  Yes, clear and dominant                       No  Yes, clear and dominant
# 23  Yes, clear and dominant                       No               Yes, clear
# 24  Yes, clear and dominant              Yes, subtle              Yes, subtle
# 25  Yes, clear and dominant                       No                       No
# 26  Yes, clear and dominant                       No                       No
# 27                       No                       No                       No
# 28  Yes, clear and dominant                       No              Yes, subtle
# 29  Yes, clear and dominant                       No               Yes, clear
# 30  Yes, clear and dominant                       No                       No
# 31  Yes, clear and dominant                       No              Yes, subtle
# 32  Yes, clear and dominant                       No              Yes, subtle
# 33  Yes, clear and dominant                       No                       No
# 34  Yes, clear and dominant                       No               Yes, clear
# 35               Yes, clear                       No              Yes, subtle
# 36  Yes, clear and dominant                       No                       No
# 37  Yes, clear and dominant                       No                       No
# 38  Yes, clear and dominant                       No              Yes, subtle
# 39                       No                       No               Yes, clear
# 40  Yes, clear and dominant                       No                       No
# 41  Yes, clear and dominant                       No              Yes, subtle
# 42  Yes, clear and dominant                       No  Yes, clear and dominant
# 43  Yes, clear and dominant                       No               Yes, clear
# 44  Yes, clear and dominant                       No              Yes, subtle
# 45  Yes, clear and dominant                       No              Yes, subtle
# 46  Yes, clear and dominant                       No                       No
# 47  Yes, clear and dominant                       No              Yes, subtle
# 48              Yes, subtle               Yes, clear              Yes, subtle
# 49  Yes, clear and dominant                       No                       No
#
#    Large Globules/Cobblestone Peripheral Globules   Peripheral Projections  \
# 0                          No                  No              Yes, subtle
# 1                          No                  No                       No
# 2                          No                  No                       No
# 3                          No                  No                       No
# 4                          No                  No                       No
# 5                          No                  No                       No
# 6     Yes, clear and dominant          Yes, clear                       No
# 7     Yes, clear and dominant                  No                       No
# 8                          No                  No                       No
# 9                          No                  No                       No
# 10                         No                  No                       No
# 11    Yes, clear and dominant         Yes, subtle                       No
# 12                         No                  No                       No
# 13                         No                  No                       No
# 14                         No                  No                       No
# 15                Yes, subtle                  No                       No
# 16                         No                  No                       No
# 17                         No                  No                       No
# 18                         No                  No                       No
# 19                         No                  No               Yes, clear
# 20                         No                  No                       No
# 21                         No         Yes, subtle              Yes, subtle
# 22                         No         Yes, subtle                       No
# 23                         No         Yes, subtle              Yes, subtle
# 24                         No                  No                       No
# 25                         No                  No                       No
# 26                         No                  No                       No
# 27                         No                  No                       No
# 28                         No                  No                       No
# 29                         No         Yes, subtle                       No
# 30    Yes, clear and dominant                  No                       No
# 31                         No                  No                       No
# 32                         No                  No                       No
# 33                         No                  No                       No
# 34                         No                  No                       No
# 35                 Yes, clear                  No                       No
# 36                         No                  No                       No
# 37                         No                  No                       No
# 38                         No                  No                       No
# 39                         No          Yes, clear                       No
# 40                         No                  No                       No
# 41                         No                  No                       No
# 42                         No                  No                       No
# 43                         No          Yes, clear                       No
# 44                         No                  No                       No
# 45                         No                  No                       No
# 46                         No                  No                       No
# 47                         No                  No                       No
# 48                         No                  No  Yes, clear and dominant
# 49                         No                  No                       No
#
#    Homogeneous Area without Vessels Homogeneous Area with Vessels  \
# 0                                No                            No
# 1                       Yes, subtle                            No
# 2           Yes, clear and dominant                            No
# 3           Yes, clear and dominant       Yes, clear and dominant
# 4                                No                            No
# 5                                No                            No
# 6                        Yes, clear                            No
# 7                                No                            No
# 8           Yes, clear and dominant                            No
# 9           Yes, clear and dominant                            No
# 10                               No                            No
# 11                               No                            No
# 12                      Yes, subtle                            No
# 13                               No                            No
# 14                               No                            No
# 15                               No                            No
# 16                               No                    Yes, clear
# 17          Yes, clear and dominant       Yes, clear and dominant
# 18                      Yes, subtle                            No
# 19                       Yes, clear                            No
# 20                               No                    Yes, clear
# 21          Yes, clear and dominant                            No
# 22                       Yes, clear                            No
# 23                      Yes, subtle                            No
# 24                               No                            No
# 25                       Yes, clear                            No
# 26                               No       Yes, clear and dominant
# 27          Yes, clear and dominant                            No
# 28          Yes, clear and dominant                            No
# 29                      Yes, subtle                            No
# 30                               No                            No
# 31                               No                            No
# 32                               No                            No
# 33          Yes, clear and dominant                            No
# 34                       Yes, clear                            No
# 35                               No       Yes, clear and dominant
# 36                       Yes, clear                            No
# 37                       Yes, clear                            No
# 38                      Yes, subtle                            No
# 39          Yes, clear and dominant                            No
# 40                               No                            No
# 41                               No                            No
# 42                               No                            No
# 43                               No                            No
# 44          Yes, clear and dominant                            No
# 45                       Yes, clear                            No
# 46                       Yes, clear                            No
# 47                               No                            No
# 48          Yes, clear and dominant                            No
# 49          Yes, clear and dominant                            No
#
#              Undefined Area Gray Regression White Regression  \
# 0               Yes, subtle              No               No
# 1                        No              No               No
# 2                Yes, clear     Yes, subtle               No
# 3   Yes, clear and dominant      Yes, clear       Yes, clear
# 4                        No              No               No
# 5                        No              No               No
# 6                        No              No               No
# 7                        No              No               No
# 8                        No              No               No
# 9                        No              No               No
# 10                       No              No               No
# 11                       No              No               No
# 12                       No      Yes, clear               No
# 13                       No              No               No
# 14              Yes, subtle              No      Yes, subtle
# 15               Yes, clear              No       Yes, clear
# 16                       No              No               No
# 17               Yes, clear              No       Yes, clear
# 18                       No              No               No
# 19  Yes, clear and dominant      Yes, clear               No
# 20  Yes, clear and dominant              No       Yes, clear
# 21  Yes, clear and dominant     Yes, subtle       Yes, clear
# 22                       No              No               No
# 23                       No      Yes, clear               No
# 24  Yes, clear and dominant     Yes, subtle               No
# 25                       No              No               No
# 26                       No              No               No
# 27                       No              No               No
# 28              Yes, subtle              No               No
# 29                       No              No               No
# 30                       No              No               No
# 31               Yes, clear              No      Yes, subtle
# 32                       No              No               No
# 33                       No              No       Yes, clear
# 34                       No              No      Yes, subtle
# 35  Yes, clear and dominant              No       Yes, clear
# 36                       No              No               No
# 37                       No              No               No
# 38                       No      Yes, clear               No
# 39              Yes, subtle              No               No
# 40                       No              No               No
# 41                       No     Yes, subtle               No
# 42                       No              No               No
# 43                       No              No               No
# 44                       No              No               No
# 45                       No              No               No
# 46                       No     Yes, subtle               No
# 47                       No              No               No
# 48                       No              No               No
# 49                       No              No       Yes, clear
#
#    Whitish Blue Veil   Chrysalis Binary label
# 0                 No          No       benign
# 1                 No          No       benign
# 2                 No          No    malignant
# 3        Yes, subtle          No    malignant
# 4                 No          No       benign
# 5                 No          No       benign
# 6                 No          No       benign
# 7                 No          No       benign
# 8                 No          No       benign
# 9                 No          No       benign
# 10                No          No       benign
# 11                No          No       benign
# 12                No          No       benign
# 13                No          No       benign
# 14                No          No       benign
# 15                No          No       benign
# 16                No          No       benign
# 17                No          No    malignant
# 18                No          No       benign
# 19                No          No    malignant
# 20        Yes, clear  Yes, clear    malignant
# 21       Yes, subtle  Yes, clear    malignant
# 22                No          No       benign
# 23        Yes, clear          No       benign
# 24                No  Yes, clear    malignant
# 25                No          No       benign
# 26                No          No       benign
# 27                No          No       benign
# 28       Yes, subtle          No       benign
# 29                No          No       benign
# 30                No          No       benign
# 31                No          No    malignant
# 32                No          No       benign
# 33                No          No       benign
# 34                No          No    malignant
# 35                No          No       benign
# 36                No          No       benign
# 37                No          No    malignant
# 38                No          No       benign
# 39                No          No       benign
# 40                No          No       benign
# 41                No          No       benign
# 42                No          No       benign
# 43                No          No       benign
# 44                No          No       benign
# 45                No          No       benign
# 46                No          No       benign
# 47                No          No       benign
# 48                No          No       benign
# 49                No          No    malignant

# %%
# Define the paths to the train and test folders
train_folder = '/Users/JUAN/Desktop/databases_qa/ISIC_2016/images/ISBI2016_ISIC_Part3_Training_Data_orig'
test_folder = '/Users/JUAN/Desktop/databases_qa/ISIC_2016/images/ISBI2016_ISIC_Part1_Test_Data_orig'

# Get the list of image filenames in the train and test folders
train_files = os.listdir(train_folder)
test_files = os.listdir(test_folder)

# Load the CSV file
df = df_fusion_mapped_sorted.copy()

# %%
test_files
# Out:
# ['ISIC_0002829.jpg',
#  'ISIC_0010587.jpg',
#  'ISIC_0009954.jpg',
#  'ISIC_0010034.jpg',
#  'ISIC_0000227.jpg',
#  'ISIC_0010020.jpg',
#  'ISIC_0000233.jpg',
#  'ISIC_0010183.jpg',
#  'ISIC_0001299.jpg',
#  'ISIC_0005000.jpg',
#  'ISIC_0000420.jpg',
#  'ISIC_0010009.jpg',
#  'ISIC_0000226.jpg',
#  'ISIC_0009564.jpg',
#  'ISIC_0000540.jpg',
#  'ISIC_0009955.jpg',
#  'ISIC_0010592.jpg',
#  'ISIC_0011101.jpg',
#  'ISIC_0009982.jpg',
#  'ISIC_0011129.jpg',
#  'ISIC_0010553.jpg',
#  'ISIC_0009994.jpg',
#  'ISIC_0009980.jpg',
#  'ISIC_0010584.jpg',
#  'ISIC_0009943.jpg',
#  'ISIC_0010023.jpg',
#  'ISIC_0000230.jpg',
#  'ISIC_0010037.jpg',
#  'ISIC_0000378.jpg',
#  'ISIC_0000393.jpg',
#  'ISIC_0010180.jpg',
#  'ISIC_0010369.jpg',
#  'ISIC_0011089.jpg',
#  'ISIC_0010368.jpg',
#  'ISIC_0010340.jpg',
#  'ISIC_0000392.jpg',
#  'ISIC_0011300.jpg',
#  'ISIC_0009201.jpg',
#  'ISIC_0000231.jpg',
#  'ISIC_0009956.jpg',
#  'ISIC_0010591.jpg',
#  'ISIC_0010234.jpg',
#  'ISIC_0000027.jpg',
#  'ISIC_0010552.jpg',
#  'ISIC_0011112.jpg',
#  'ISIC_0000037.jpg',
#  'ISIC_0010556.jpg',
#  'ISIC_0000023.jpg',
#  'ISIC_0009946.jpg',
#  'ISIC_0011310.jpg',
#  'ISIC_0001103.jpg',
#  'ISIC_0011338.jpg',
#  'ISIC_0003728.jpg',
#  'ISIC_0000547.jpg',
#  'ISIC_0000433.jpg',
#  'ISIC_0010378.jpg',
#  'ISIC_0011098.jpg',
#  'ISIC_0000195.jpg',
#  'ISIC_0010437.jpg',
#  'ISIC_0010379.jpg',
#  'ISIC_0010190.jpg',
#  'ISIC_0000354.jpg',
#  'ISIC_0000340.jpg',
#  'ISIC_0000368.jpg',
#  'ISIC_0010033.jpg',
#  'ISIC_0000234.jpg',
#  'ISIC_0011305.jpg',
#  'ISIC_0000022.jpg',
#  'ISIC_0010231.jpg',
#  'ISIC_0000036.jpg',
#  'ISIC_0011107.jpg',
#  'ISIC_0009990.jpg',
#  'ISIC_0009992.jpg',
#  'ISIC_0000020.jpg',
#  'ISIC_0009945.jpg',
#  'ISIC_0010596.jpg',
#  'ISIC_0010582.jpg',
#  'ISIC_0001100.jpg',
#  'ISIC_0000222.jpg',
#  'ISIC_0001128.jpg',
#  'ISIC_0000550.jpg',
#  'ISIC_0000418.jpg',
#  'ISIC_0011298.jpg',
#  'ISIC_0010192.jpg',
#  'ISIC_0010347.jpg',
#  'ISIC_0000197.jpg',
#  'ISIC_0000196.jpg',
#  'ISIC_0000141.jpg',
#  'ISIC_0010346.jpg',
#  'ISIC_0000169.jpg',
#  'ISIC_0000380.jpg',
#  'ISIC_0010193.jpg',
#  'ISIC_0010187.jpg',
#  'ISIC_0000343.jpg',
#  'ISIC_0000357.jpg',
#  'ISIC_0010018.jpg',
#  'ISIC_0010597.jpg',
#  'ISIC_0011104.jpg',
#  'ISIC_0009993.jpg',
#  'ISIC_0011110.jpg',
#  'ISIC_0010255.jpg',
#  'ISIC_0000052.jpg',
#  'ISIC_0011177.jpg',
#  'ISIC_0009923.jpg',
#  'ISIC_0011349.jpg',
#  'ISIC_0000287.jpg',
#  'ISIC_0000456.jpg',
#  'ISIC_0000132.jpg',
#  'ISIC_0000126.jpg',
#  'ISIC_0001204.jpg',
#  'ISIC_0009880.jpg',
#  'ISIC_0009881.jpg',
#  'ISIC_0010452.jpg',
#  'ISIC_0010863.jpg',
#  'ISIC_0000494.jpg',
#  'ISIC_0000319.jpg',
#  'ISIC_0000325.jpg',
#  'ISIC_0000279.jpg',
#  'ISIC_0011374.jpg',
#  'ISIC_0000537.jpg',
#  'ISIC_0011162.jpg',
#  'ISIC_0011176.jpg',
#  'ISIC_0000053.jpg',
#  'ISIC_0010254.jpg',
#  'ISIC_0011148.jpg',
#  'ISIC_0000092.jpg',
#  'ISIC_0009920.jpg',
#  'ISIC_0000253.jpg',
#  'ISIC_0000509.jpg',
#  'ISIC_0006193.jpg',
#  'ISIC_0000327.jpg',
#  'ISIC_0000482.jpg',
#  'ISIC_0010336.jpg',
#  'ISIC_0000125.jpg',
#  'ISIC_0010444.jpg',
#  'ISIC_0009869.jpg',
#  'ISIC_0009882.jpg',
#  'ISIC_0010451.jpg',
#  'ISIC_0008626.jpg',
#  'ISIC_0000508.jpg',
#  'ISIC_0011363.jpg',
#  'ISIC_0000246.jpg',
#  'ISIC_0010055.jpg',
#  'ISIC_0000534.jpg',
#  'ISIC_0010041.jpg',
#  'ISIC_0011175.jpg',
#  'ISIC_0011149.jpg',
#  'ISIC_0010257.jpg',
#  'ISIC_0003559.jpg',
#  'ISIC_0011171.jpg',
#  'ISIC_0000040.jpg',
#  'ISIC_0009931.jpg',
#  'ISIC_0011367.jpg',
#  'ISIC_0000518.jpg',
#  'ISIC_0010092.jpg',
#  'ISIC_0011213.jpg',
#  'ISIC_0000487.jpg',
#  'ISIC_0004346.jpg',
#  'ISIC_0009879.jpg',
#  'ISIC_0010483.jpg',
#  'ISIC_0010326.jpg',
#  'ISIC_0010454.jpg',
#  'ISIC_0002246.jpg',
#  'ISIC_0000479.jpg',
#  'ISIC_0009298.jpg',
#  'ISIC_0000525.jpg',
#  'ISIC_0000257.jpg',
#  'ISIC_0009918.jpg',
#  'ISIC_0002871.jpg',
#  'ISIC_0009930.jpg',
#  'ISIC_0000069.jpg',
#  'ISIC_0011172.jpg',
#  'ISIC_0000043.jpg',
#  'ISIC_0000057.jpg',
#  'ISIC_0009926.jpg',
#  'ISIC_0000527.jpg',
#  'ISIC_0000533.jpg',
#  'ISIC_0011204.jpg',
#  'ISIC_0000490.jpg',
#  'ISIC_0000484.jpg',
#  'ISIC_0009891.jpg',
#  'ISIC_0009885.jpg',
#  'ISIC_0010456.jpg',
#  'ISIC_0010494.jpg',
#  'ISIC_0010331.jpg',
#  'ISIC_0000136.jpg',
#  'ISIC_0000320.jpg',
#  'ISIC_0008998.jpg',
#  'ISIC_0011205.jpg',
#  'ISIC_0010047.jpg',
#  'ISIC_0000254.jpg',
#  'ISIC_0011359.jpg',
#  'ISIC_0009927.jpg',
#  'ISIC_0000056.jpg',
#  'ISIC_0011167.jpg',
#  'ISIC_0009902.jpg',
#  'ISIC_0000098.jpg',
#  'ISIC_0010062.jpg',
#  'ISIC_0000271.jpg',
#  'ISIC_0010089.jpg',
#  'ISIC_0001190.jpg',
#  'ISIC_0000311.jpg',
#  'ISIC_0009889.jpg',
#  'ISIC_0000113.jpg',
#  'ISIC_0000107.jpg',
#  'ISIC_0010498.jpg',
#  'ISIC_0010856.jpg',
#  'ISIC_0000476.jpg',
#  'ISIC_0010103.jpg',
#  'ISIC_0000310.jpg',
#  'ISIC_0001185.jpg',
#  'ISIC_0010088.jpg',
#  'ISIC_0000258.jpg',
#  'ISIC_0010077.jpg',
#  'ISIC_0000099.jpg',
#  'ISIC_0011143.jpg',
#  'ISIC_0008406.jpg',
#  'ISIC_0010261.jpg',
#  'ISIC_0000072.jpg',
#  'ISIC_0000066.jpg',
#  'ISIC_0002673.jpg',
#  'ISIC_0000064.jpg',
#  'ISIC_0011155.jpg',
#  'ISIC_0009083.jpg',
#  'ISIC_0009901.jpg',
#  'ISIC_0010061.jpg',
#  'ISIC_0000299.jpg',
#  'ISIC_0000306.jpg',
#  'ISIC_0000448.jpg',
#  'ISIC_0010854.jpg',
#  'ISIC_0000138.jpg',
#  'ISIC_0009874.jpg',
#  'ISIC_0000111.jpg',
#  'ISIC_0000449.jpg',
#  'ISIC_0010100.jpg',
#  'ISIC_0001186.jpg',
#  'ISIC_0000298.jpg',
#  'ISIC_0000501.jpg',
#  'ISIC_0000515.jpg',
#  'ISIC_0009928.jpg',
#  'ISIC_0011168.jpg',
#  'ISIC_0000071.jpg',
#  'ISIC_0011150.jpg',
#  'ISIC_0010058.jpg',
#  'ISIC_0000539.jpg',
#  'ISIC_0007322.jpg',
#  'ISIC_0001960.jpg',
#  'ISIC_0008207.jpg',
#  'ISIC_0010448.jpg',
#  'ISIC_0000129.jpg',
#  'ISIC_0010474.jpg',
#  'ISIC_0000101.jpg',
#  'ISIC_0000115.jpg',
#  'ISIC_0010460.jpg',
#  'ISIC_0010449.jpg',
#  'ISIC_0000470.jpg',
#  'ISIC_0008992.jpg',
#  'ISIC_0000302.jpg',
#  'ISIC_0011227.jpg',
#  'ISIC_0011384.jpg',
#  'ISIC_0000289.jpg',
#  'ISIC_0000510.jpg',
#  'ISIC_0010059.jpg',
#  'ISIC_0011151.jpg',
#  'ISIC_0009078.jpg',
#  'ISIC_0002107.jpg',
#  'ISIC_0001142.jpg',
#  'ISIC_0008600.jpg',
#  'ISIC_0010073.jpg',
#  'ISIC_0011392.jpg',
#  'ISIC_0001181.jpg',
#  'ISIC_0011386.jpg',
#  'ISIC_0000328.jpg',
#  'ISIC_0011219.jpg',
#  'ISIC_0000466.jpg',
#  'ISIC_0010846.jpg',
#  'ISIC_0000499.jpg',
#  'ISIC_0010463.jpg',
#  'ISIC_0009898.jpg',
#  'ISIC_0010477.jpg',
#  'ISIC_0007693.jpg',
#  'ISIC_0009872.jpg',
#  'ISIC_0000117.jpg',
#  'ISIC_0010847.jpg',
#  'ISIC_0011224.jpg',
#  'ISIC_0011344.jpg',
#  'ISIC_0000088.jpg',
#  'ISIC_0009906.jpg',
#  'ISIC_0001427.jpg',
#  'ISIC_0011152.jpg',
#  'ISIC_0010565.jpg',
#  'ISIC_0000212.jpg',
#  'ISIC_0010607.jpg',
#  'ISIC_0010175.jpg',
#  'ISIC_0011294.jpg',
#  'ISIC_0010377.jpg',
#  'ISIC_0000164.jpg',
#  'ISIC_0011083.jpg',
#  'ISIC_0000165.jpg',
#  'ISIC_0004115.jpg',
#  'ISIC_0010606.jpg',
#  'ISIC_0000549.jpg',
#  'ISIC_0001131.jpg',
#  'ISIC_0010028.jpg',
#  'ISIC_0011336.jpg',
#  'ISIC_0000213.jpg',
#  'ISIC_0009948.jpg',
#  'ISIC_0010202.jpg',
#  'ISIC_0009035.jpg',
#  'ISIC_0010216.jpg',
#  'ISIC_0000013.jpg',
#  'ISIC_0011122.jpg',
#  'ISIC_0010599.jpg',
#  'ISIC_0010016.jpg',
#  'ISIC_0008659.jpg',
#  'ISIC_0003056.jpg',
#  'ISIC_0010604.jpg',
#  'ISIC_0000371.jpg',
#  'ISIC_0010374.jpg',
#  'ISIC_0010360.jpg',
#  'ISIC_0008507.jpg',
#  'ISIC_0010348.jpg',
#  'ISIC_0000198.jpg',
#  'ISIC_0011081.jpg',
#  'ISIC_0011080.jpg',
#  'ISIC_0000172.jpg',
#  'ISIC_0011321.jpg',
#  'ISIC_0008116.jpg',
#  'ISIC_0010598.jpg',
#  'ISIC_0009977.jpg',
#  'ISIC_0010229.jpg',
#  'ISIC_0010215.jpg',
#  'ISIC_0010201.jpg',
#  'ISIC_0009988.jpg',
#  'ISIC_0000012.jpg',
#  'ISIC_0009998.jpg',
#  'ISIC_0010588.jpg',
#  'ISIC_0011325.jpg',
#  'ISIC_0000228.jpg',
#  'ISIC_0011319.jpg',
#  'ISIC_0000200.jpg',
#  'ISIC_0010013.jpg',
#  'ISIC_0010173.jpg',
#  'ISIC_0006711.jpg',
#  'ISIC_0011292.jpg',
#  'ISIC_0011090.jpg',
#  'ISIC_0000188.jpg',
#  'ISIC_0000177.jpg',
#  'ISIC_0000407.jpg',
#  'ISIC_0000201.jpg',
#  'ISIC_0001484.jpg',
#  'ISIC_0000003.jpg',
#  'ISIC_0011132.jpg',
#  'ISIC_0010238.jpg',
#  'ISIC_0010574.jpg',
#  'ISIC_0010206.jpg',
#  'ISIC_0000015.jpg',
#  'ISIC_0009970.jpg',
#  'ISIC_0009958.jpg',
#  'ISIC_0010038.jpg',
#  'ISIC_0010004.jpg',
#  'ISIC_0000377.jpg',
#  'ISIC_0000388.jpg',
#  'ISIC_0000149.jpg',
#  'ISIC_0000161.jpg',
#  'ISIC_0011092.jpg',
#  'ISIC_0010373.jpg',
#  'ISIC_0000160.jpg',
#  'ISIC_0000174.jpg',
#  'ISIC_0001242.jpg',
#  'ISIC_0010171.jpg',
#  'ISIC_0001685.jpg',
#  'ISIC_0010011.jpg',
#  'ISIC_0000202.jpg',
#  'ISIC_0011333.jpg',
#  'ISIC_0009959.jpg',
#  'ISIC_0009965.jpg',
#  'ISIC_0000014.jpg',
#  'ISIC_0010207.jpg']

# %%
# Create a mapping dictionary for the train and test filenames
train_mapping = {filename.split('.')[0]: f"train_{i:07d}" for i, filename in enumerate(train_files)}
test_mapping = {filename.split('.')[0]: f"test_{i:07d}" for i, filename in enumerate(test_files)}

# %%
test_mapping
# Out:
# {'ISIC_0002829': 'test_0000000',
#  'ISIC_0010587': 'test_0000001',
#  'ISIC_0009954': 'test_0000002',
#  'ISIC_0010034': 'test_0000003',
#  'ISIC_0000227': 'test_0000004',
#  'ISIC_0010020': 'test_0000005',
#  'ISIC_0000233': 'test_0000006',
#  'ISIC_0010183': 'test_0000007',
#  'ISIC_0001299': 'test_0000008',
#  'ISIC_0005000': 'test_0000009',
#  'ISIC_0000420': 'test_0000010',
#  'ISIC_0010009': 'test_0000011',
#  'ISIC_0000226': 'test_0000012',
#  'ISIC_0009564': 'test_0000013',
#  'ISIC_0000540': 'test_0000014',
#  'ISIC_0009955': 'test_0000015',
#  'ISIC_0010592': 'test_0000016',
#  'ISIC_0011101': 'test_0000017',
#  'ISIC_0009982': 'test_0000018',
#  'ISIC_0011129': 'test_0000019',
#  'ISIC_0010553': 'test_0000020',
#  'ISIC_0009994': 'test_0000021',
#  'ISIC_0009980': 'test_0000022',
#  'ISIC_0010584': 'test_0000023',
#  'ISIC_0009943': 'test_0000024',
#  'ISIC_0010023': 'test_0000025',
#  'ISIC_0000230': 'test_0000026',
#  'ISIC_0010037': 'test_0000027',
#  'ISIC_0000378': 'test_0000028',
#  'ISIC_0000393': 'test_0000029',
#  'ISIC_0010180': 'test_0000030',
#  'ISIC_0010369': 'test_0000031',
#  'ISIC_0011089': 'test_0000032',
#  'ISIC_0010368': 'test_0000033',
#  'ISIC_0010340': 'test_0000034',
#  'ISIC_0000392': 'test_0000035',
#  'ISIC_0011300': 'test_0000036',
#  'ISIC_0009201': 'test_0000037',
#  'ISIC_0000231': 'test_0000038',
#  'ISIC_0009956': 'test_0000039',
#  'ISIC_0010591': 'test_0000040',
#  'ISIC_0010234': 'test_0000041',
#  'ISIC_0000027': 'test_0000042',
#  'ISIC_0010552': 'test_0000043',
#  'ISIC_0011112': 'test_0000044',
#  'ISIC_0000037': 'test_0000045',
#  'ISIC_0010556': 'test_0000046',
#  'ISIC_0000023': 'test_0000047',
#  'ISIC_0009946': 'test_0000048',
#  'ISIC_0011310': 'test_0000049',
#  'ISIC_0001103': 'test_0000050',
#  'ISIC_0011338': 'test_0000051',
#  'ISIC_0003728': 'test_0000052',
#  'ISIC_0000547': 'test_0000053',
#  'ISIC_0000433': 'test_0000054',
#  'ISIC_0010378': 'test_0000055',
#  'ISIC_0011098': 'test_0000056',
#  'ISIC_0000195': 'test_0000057',
#  'ISIC_0010437': 'test_0000058',
#  'ISIC_0010379': 'test_0000059',
#  'ISIC_0010190': 'test_0000060',
#  'ISIC_0000354': 'test_0000061',
#  'ISIC_0000340': 'test_0000062',
#  'ISIC_0000368': 'test_0000063',
#  'ISIC_0010033': 'test_0000064',
#  'ISIC_0000234': 'test_0000065',
#  'ISIC_0011305': 'test_0000066',
#  'ISIC_0000022': 'test_0000067',
#  'ISIC_0010231': 'test_0000068',
#  'ISIC_0000036': 'test_0000069',
#  'ISIC_0011107': 'test_0000070',
#  'ISIC_0009990': 'test_0000071',
#  'ISIC_0009992': 'test_0000072',
#  'ISIC_0000020': 'test_0000073',
#  'ISIC_0009945': 'test_0000074',
#  'ISIC_0010596': 'test_0000075',
#  'ISIC_0010582': 'test_0000076',
#  'ISIC_0001100': 'test_0000077',
#  'ISIC_0000222': 'test_0000078',
#  'ISIC_0001128': 'test_0000079',
#  'ISIC_0000550': 'test_0000080',
#  'ISIC_0000418': 'test_0000081',
#  'ISIC_0011298': 'test_0000082',
#  'ISIC_0010192': 'test_0000083',
#  'ISIC_0010347': 'test_0000084',
#  'ISIC_0000197': 'test_0000085',
#  'ISIC_0000196': 'test_0000086',
#  'ISIC_0000141': 'test_0000087',
#  'ISIC_0010346': 'test_0000088',
#  'ISIC_0000169': 'test_0000089',
#  'ISIC_0000380': 'test_0000090',
#  'ISIC_0010193': 'test_0000091',
#  'ISIC_0010187': 'test_0000092',
#  'ISIC_0000343': 'test_0000093',
#  'ISIC_0000357': 'test_0000094',
#  'ISIC_0010018': 'test_0000095',
#  'ISIC_0010597': 'test_0000096',
#  'ISIC_0011104': 'test_0000097',
#  'ISIC_0009993': 'test_0000098',
#  'ISIC_0011110': 'test_0000099',
#  'ISIC_0010255': 'test_0000100',
#  'ISIC_0000052': 'test_0000101',
#  'ISIC_0011177': 'test_0000102',
#  'ISIC_0009923': 'test_0000103',
#  'ISIC_0011349': 'test_0000104',
#  'ISIC_0000287': 'test_0000105',
#  'ISIC_0000456': 'test_0000106',
#  'ISIC_0000132': 'test_0000107',
#  'ISIC_0000126': 'test_0000108',
#  'ISIC_0001204': 'test_0000109',
#  'ISIC_0009880': 'test_0000110',
#  'ISIC_0009881': 'test_0000111',
#  'ISIC_0010452': 'test_0000112',
#  'ISIC_0010863': 'test_0000113',
#  'ISIC_0000494': 'test_0000114',
#  'ISIC_0000319': 'test_0000115',
#  'ISIC_0000325': 'test_0000116',
#  'ISIC_0000279': 'test_0000117',
#  'ISIC_0011374': 'test_0000118',
#  'ISIC_0000537': 'test_0000119',
#  'ISIC_0011162': 'test_0000120',
#  'ISIC_0011176': 'test_0000121',
#  'ISIC_0000053': 'test_0000122',
#  'ISIC_0010254': 'test_0000123',
#  'ISIC_0011148': 'test_0000124',
#  'ISIC_0000092': 'test_0000125',
#  'ISIC_0009920': 'test_0000126',
#  'ISIC_0000253': 'test_0000127',
#  'ISIC_0000509': 'test_0000128',
#  'ISIC_0006193': 'test_0000129',
#  'ISIC_0000327': 'test_0000130',
#  'ISIC_0000482': 'test_0000131',
#  'ISIC_0010336': 'test_0000132',
#  'ISIC_0000125': 'test_0000133',
#  'ISIC_0010444': 'test_0000134',
#  'ISIC_0009869': 'test_0000135',
#  'ISIC_0009882': 'test_0000136',
#  'ISIC_0010451': 'test_0000137',
#  'ISIC_0008626': 'test_0000138',
#  'ISIC_0000508': 'test_0000139',
#  'ISIC_0011363': 'test_0000140',
#  'ISIC_0000246': 'test_0000141',
#  'ISIC_0010055': 'test_0000142',
#  'ISIC_0000534': 'test_0000143',
#  'ISIC_0010041': 'test_0000144',
#  'ISIC_0011175': 'test_0000145',
#  'ISIC_0011149': 'test_0000146',
#  'ISIC_0010257': 'test_0000147',
#  'ISIC_0003559': 'test_0000148',
#  'ISIC_0011171': 'test_0000149',
#  'ISIC_0000040': 'test_0000150',
#  'ISIC_0009931': 'test_0000151',
#  'ISIC_0011367': 'test_0000152',
#  'ISIC_0000518': 'test_0000153',
#  'ISIC_0010092': 'test_0000154',
#  'ISIC_0011213': 'test_0000155',
#  'ISIC_0000487': 'test_0000156',
#  'ISIC_0004346': 'test_0000157',
#  'ISIC_0009879': 'test_0000158',
#  'ISIC_0010483': 'test_0000159',
#  'ISIC_0010326': 'test_0000160',
#  'ISIC_0010454': 'test_0000161',
#  'ISIC_0002246': 'test_0000162',
#  'ISIC_0000479': 'test_0000163',
#  'ISIC_0009298': 'test_0000164',
#  'ISIC_0000525': 'test_0000165',
#  'ISIC_0000257': 'test_0000166',
#  'ISIC_0009918': 'test_0000167',
#  'ISIC_0002871': 'test_0000168',
#  'ISIC_0009930': 'test_0000169',
#  'ISIC_0000069': 'test_0000170',
#  'ISIC_0011172': 'test_0000171',
#  'ISIC_0000043': 'test_0000172',
#  'ISIC_0000057': 'test_0000173',
#  'ISIC_0009926': 'test_0000174',
#  'ISIC_0000527': 'test_0000175',
#  'ISIC_0000533': 'test_0000176',
#  'ISIC_0011204': 'test_0000177',
#  'ISIC_0000490': 'test_0000178',
#  'ISIC_0000484': 'test_0000179',
#  'ISIC_0009891': 'test_0000180',
#  'ISIC_0009885': 'test_0000181',
#  'ISIC_0010456': 'test_0000182',
#  'ISIC_0010494': 'test_0000183',
#  'ISIC_0010331': 'test_0000184',
#  'ISIC_0000136': 'test_0000185',
#  'ISIC_0000320': 'test_0000186',
#  'ISIC_0008998': 'test_0000187',
#  'ISIC_0011205': 'test_0000188',
#  'ISIC_0010047': 'test_0000189',
#  'ISIC_0000254': 'test_0000190',
#  'ISIC_0011359': 'test_0000191',
#  'ISIC_0009927': 'test_0000192',
#  'ISIC_0000056': 'test_0000193',
#  'ISIC_0011167': 'test_0000194',
#  'ISIC_0009902': 'test_0000195',
#  'ISIC_0000098': 'test_0000196',
#  'ISIC_0010062': 'test_0000197',
#  'ISIC_0000271': 'test_0000198',
#  'ISIC_0010089': 'test_0000199',
#  'ISIC_0001190': 'test_0000200',
#  'ISIC_0000311': 'test_0000201',
#  'ISIC_0009889': 'test_0000202',
#  'ISIC_0000113': 'test_0000203',
#  'ISIC_0000107': 'test_0000204',
#  'ISIC_0010498': 'test_0000205',
#  'ISIC_0010856': 'test_0000206',
#  'ISIC_0000476': 'test_0000207',
#  'ISIC_0010103': 'test_0000208',
#  'ISIC_0000310': 'test_0000209',
#  'ISIC_0001185': 'test_0000210',
#  'ISIC_0010088': 'test_0000211',
#  'ISIC_0000258': 'test_0000212',
#  'ISIC_0010077': 'test_0000213',
#  'ISIC_0000099': 'test_0000214',
#  'ISIC_0011143': 'test_0000215',
#  'ISIC_0008406': 'test_0000216',
#  'ISIC_0010261': 'test_0000217',
#  'ISIC_0000072': 'test_0000218',
#  'ISIC_0000066': 'test_0000219',
#  'ISIC_0002673': 'test_0000220',
#  'ISIC_0000064': 'test_0000221',
#  'ISIC_0011155': 'test_0000222',
#  'ISIC_0009083': 'test_0000223',
#  'ISIC_0009901': 'test_0000224',
#  'ISIC_0010061': 'test_0000225',
#  'ISIC_0000299': 'test_0000226',
#  'ISIC_0000306': 'test_0000227',
#  'ISIC_0000448': 'test_0000228',
#  'ISIC_0010854': 'test_0000229',
#  'ISIC_0000138': 'test_0000230',
#  'ISIC_0009874': 'test_0000231',
#  'ISIC_0000111': 'test_0000232',
#  'ISIC_0000449': 'test_0000233',
#  'ISIC_0010100': 'test_0000234',
#  'ISIC_0001186': 'test_0000235',
#  'ISIC_0000298': 'test_0000236',
#  'ISIC_0000501': 'test_0000237',
#  'ISIC_0000515': 'test_0000238',
#  'ISIC_0009928': 'test_0000239',
#  'ISIC_0011168': 'test_0000240',
#  'ISIC_0000071': 'test_0000241',
#  'ISIC_0011150': 'test_0000242',
#  'ISIC_0010058': 'test_0000243',
#  'ISIC_0000539': 'test_0000244',
#  'ISIC_0007322': 'test_0000245',
#  'ISIC_0001960': 'test_0000246',
#  'ISIC_0008207': 'test_0000247',
#  'ISIC_0010448': 'test_0000248',
#  'ISIC_0000129': 'test_0000249',
#  'ISIC_0010474': 'test_0000250',
#  'ISIC_0000101': 'test_0000251',
#  'ISIC_0000115': 'test_0000252',
#  'ISIC_0010460': 'test_0000253',
#  'ISIC_0010449': 'test_0000254',
#  'ISIC_0000470': 'test_0000255',
#  'ISIC_0008992': 'test_0000256',
#  'ISIC_0000302': 'test_0000257',
#  'ISIC_0011227': 'test_0000258',
#  'ISIC_0011384': 'test_0000259',
#  'ISIC_0000289': 'test_0000260',
#  'ISIC_0000510': 'test_0000261',
#  'ISIC_0010059': 'test_0000262',
#  'ISIC_0011151': 'test_0000263',
#  'ISIC_0009078': 'test_0000264',
#  'ISIC_0002107': 'test_0000265',
#  'ISIC_0001142': 'test_0000266',
#  'ISIC_0008600': 'test_0000267',
#  'ISIC_0010073': 'test_0000268',
#  'ISIC_0011392': 'test_0000269',
#  'ISIC_0001181': 'test_0000270',
#  'ISIC_0011386': 'test_0000271',
#  'ISIC_0000328': 'test_0000272',
#  'ISIC_0011219': 'test_0000273',
#  'ISIC_0000466': 'test_0000274',
#  'ISIC_0010846': 'test_0000275',
#  'ISIC_0000499': 'test_0000276',
#  'ISIC_0010463': 'test_0000277',
#  'ISIC_0009898': 'test_0000278',
#  'ISIC_0010477': 'test_0000279',
#  'ISIC_0007693': 'test_0000280',
#  'ISIC_0009872': 'test_0000281',
#  'ISIC_0000117': 'test_0000282',
#  'ISIC_0010847': 'test_0000283',
#  'ISIC_0011224': 'test_0000284',
#  'ISIC_0011344': 'test_0000285',
#  'ISIC_0000088': 'test_0000286',
#  'ISIC_0009906': 'test_0000287',
#  'ISIC_0001427': 'test_0000288',
#  'ISIC_0011152': 'test_0000289',
#  'ISIC_0010565': 'test_0000290',
#  'ISIC_0000212': 'test_0000291',
#  'ISIC_0010607': 'test_0000292',
#  'ISIC_0010175': 'test_0000293',
#  'ISIC_0011294': 'test_0000294',
#  'ISIC_0010377': 'test_0000295',
#  'ISIC_0000164': 'test_0000296',
#  'ISIC_0011083': 'test_0000297',
#  'ISIC_0000165': 'test_0000298',
#  'ISIC_0004115': 'test_0000299',
#  'ISIC_0010606': 'test_0000300',
#  'ISIC_0000549': 'test_0000301',
#  'ISIC_0001131': 'test_0000302',
#  'ISIC_0010028': 'test_0000303',
#  'ISIC_0011336': 'test_0000304',
#  'ISIC_0000213': 'test_0000305',
#  'ISIC_0009948': 'test_0000306',
#  'ISIC_0010202': 'test_0000307',
#  'ISIC_0009035': 'test_0000308',
#  'ISIC_0010216': 'test_0000309',
#  'ISIC_0000013': 'test_0000310',
#  'ISIC_0011122': 'test_0000311',
#  'ISIC_0010599': 'test_0000312',
#  'ISIC_0010016': 'test_0000313',
#  'ISIC_0008659': 'test_0000314',
#  'ISIC_0003056': 'test_0000315',
#  'ISIC_0010604': 'test_0000316',
#  'ISIC_0000371': 'test_0000317',
#  'ISIC_0010374': 'test_0000318',
#  'ISIC_0010360': 'test_0000319',
#  'ISIC_0008507': 'test_0000320',
#  'ISIC_0010348': 'test_0000321',
#  'ISIC_0000198': 'test_0000322',
#  'ISIC_0011081': 'test_0000323',
#  'ISIC_0011080': 'test_0000324',
#  'ISIC_0000172': 'test_0000325',
#  'ISIC_0011321': 'test_0000326',
#  'ISIC_0008116': 'test_0000327',
#  'ISIC_0010598': 'test_0000328',
#  'ISIC_0009977': 'test_0000329',
#  'ISIC_0010229': 'test_0000330',
#  'ISIC_0010215': 'test_0000331',
#  'ISIC_0010201': 'test_0000332',
#  'ISIC_0009988': 'test_0000333',
#  'ISIC_0000012': 'test_0000334',
#  'ISIC_0009998': 'test_0000335',
#  'ISIC_0010588': 'test_0000336',
#  'ISIC_0011325': 'test_0000337',
#  'ISIC_0000228': 'test_0000338',
#  'ISIC_0011319': 'test_0000339',
#  'ISIC_0000200': 'test_0000340',
#  'ISIC_0010013': 'test_0000341',
#  'ISIC_0010173': 'test_0000342',
#  'ISIC_0006711': 'test_0000343',
#  'ISIC_0011292': 'test_0000344',
#  'ISIC_0011090': 'test_0000345',
#  'ISIC_0000188': 'test_0000346',
#  'ISIC_0000177': 'test_0000347',
#  'ISIC_0000407': 'test_0000348',
#  'ISIC_0000201': 'test_0000349',
#  'ISIC_0001484': 'test_0000350',
#  'ISIC_0000003': 'test_0000351',
#  'ISIC_0011132': 'test_0000352',
#  'ISIC_0010238': 'test_0000353',
#  'ISIC_0010574': 'test_0000354',
#  'ISIC_0010206': 'test_0000355',
#  'ISIC_0000015': 'test_0000356',
#  'ISIC_0009970': 'test_0000357',
#  'ISIC_0009958': 'test_0000358',
#  'ISIC_0010038': 'test_0000359',
#  'ISIC_0010004': 'test_0000360',
#  'ISIC_0000377': 'test_0000361',
#  'ISIC_0000388': 'test_0000362',
#  'ISIC_0000149': 'test_0000363',
#  'ISIC_0000161': 'test_0000364',
#  'ISIC_0011092': 'test_0000365',
#  'ISIC_0010373': 'test_0000366',
#  'ISIC_0000160': 'test_0000367',
#  'ISIC_0000174': 'test_0000368',
#  'ISIC_0001242': 'test_0000369',
#  'ISIC_0010171': 'test_0000370',
#  'ISIC_0001685': 'test_0000371',
#  'ISIC_0010011': 'test_0000372',
#  'ISIC_0000202': 'test_0000373',
#  'ISIC_0011333': 'test_0000374',
#  'ISIC_0009959': 'test_0000375',
#  'ISIC_0009965': 'test_0000376',
#  'ISIC_0000014': 'test_0000377',
#  'ISIC_0010207': 'test_0000378'}

# %%
# Iterate over each observation in the dataframe
for index, row in df.iterrows():
    file_name = row['File name (.jpg)']
    
    # Check if the file name is in the train_mapping dictionary
    if file_name in train_mapping:
        new_id = train_mapping[file_name]
    # Check if the file name is in the test_mapping dictionary
    elif file_name in test_mapping:
        new_id = test_mapping[file_name]
    else:
        new_id = None
    
    # Update the 'New Image ID' variable with the new_id value
    df.loc[index, 'New Image ID'] = new_id

# %%
# Reorder the columns with 'New Image ID' in the second position
column_order = ['File name (.jpg)', 'New Image ID'] + [col for col in df.columns if col not in ['File name (.jpg)', 'New Image ID']]
df = df.reindex(columns=column_order)
# Filter train data
train_df = df[df['New Image ID'].str.startswith('train', na=False)]
# Filter test data
test_df = df[df['New Image ID'].str.startswith('test', na=False)]

# %%
train_df
# Out:
#     File name (.jpg)   New Image ID                           Global Pattern  \
# 2       ISIC_0000002  train_0000398          Mixed (mix of two of the above)
# 3       ISIC_0000004  train_0000347  Multicomponent (mix of 3 or more above)
# 14      ISIC_0000021  train_0000103                        Diffuse Reticular
# 17      ISIC_0000026  train_0000033  Multicomponent (mix of 3 or more above)
# 18      ISIC_0000028  train_0000439                        Diffuse Reticular
# ..               ...            ...                                      ...
# 893     ISIC_0011387  train_0000338                                Undefined
# 894     ISIC_0011390  train_0000310                                Undefined
# 896     ISIC_0011397  train_0000246                                Undefined
# 897     ISIC_0011398  train_0000179                        Diffuse Reticular
# 899     ISIC_0011402  train_0000216                        Diffuse Reticular
#
#          Pigmented Reticulum Negative Reticulum Small Dots/Globules  \
# 2    Yes, clear and dominant                 No                  No
# 3                Yes, subtle                 No                  No
# 14   Yes, clear and dominant                 No          Yes, clear
# 17               Yes, subtle                 No          Yes, clear
# 18   Yes, clear and dominant                 No                  No
# ..                       ...                ...                 ...
# 893                       No                 No                  No
# 894              Yes, subtle                 No          Yes, clear
# 896                       No                 No          Yes, clear
# 897  Yes, clear and dominant                 No         Yes, subtle
# 899  Yes, clear and dominant                 No                  No
#
#     Large Globules/Cobblestone Peripheral Globules Peripheral Projections  \
# 2                           No                  No                     No
# 3                           No                  No                     No
# 14                          No                  No                     No
# 17                          No                  No                     No
# 18                          No                  No                     No
# ..                         ...                 ...                    ...
# 893                         No                  No                     No
# 894                         No                  No                     No
# 896                         No         Yes, subtle                     No
# 897                         No                  No                     No
# 899                         No                  No                     No
#
#     Homogeneous Area without Vessels Homogeneous Area with Vessels  \
# 2            Yes, clear and dominant                            No
# 3            Yes, clear and dominant       Yes, clear and dominant
# 14                                No                            No
# 17           Yes, clear and dominant       Yes, clear and dominant
# 18                       Yes, subtle                            No
# ..                               ...                           ...
# 893                               No                            No
# 894                               No                            No
# 896                               No                            No
# 897                               No                            No
# 899                               No                            No
#
#               Undefined Area Gray Regression White Regression  \
# 2                 Yes, clear     Yes, subtle               No
# 3    Yes, clear and dominant      Yes, clear       Yes, clear
# 14               Yes, subtle              No      Yes, subtle
# 17                Yes, clear              No       Yes, clear
# 18                        No              No               No
# ..                       ...             ...              ...
# 893  Yes, clear and dominant     Yes, subtle               No
# 894                       No     Yes, subtle               No
# 896                       No      Yes, clear               No
# 897                       No              No               No
# 899                       No              No               No
#
#     Whitish Blue Veil Chrysalis Binary label
# 2                  No        No    malignant
# 3         Yes, subtle        No    malignant
# 14                 No        No       benign
# 17                 No        No    malignant
# 18                 No        No       benign
# ..                ...       ...          ...
# 893                No        No    malignant
# 894                No        No    malignant
# 896                No        No       benign
# 897                No        No       benign
# 899                No        No       benign
#
# [440 rows x 17 columns]

# %%
df_fusion_mapped.to_csv('../../data/processed/df_fusion_clean.csv', index=False)
