# %% [markdown]
# # Data Cleaning and Question/Answer Definition

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
from translate import Translator
# Out:
# /var/folders/mn/j0njpy6d2bq9_w2n1s6tt2gh0000gn/T/ipykernel_67407/3047096876.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Mapping Questions/Answers

# %%
df_fusion = pd.read_csv('../../data/raw/fusion_challenge_datos.csv', delimiter=';')
df_melanoma = pd.read_csv('../../data/raw/base_datos_melanomas.csv', delimiter=';', encoding='utf-8')

# %%
df_fusion
# Out:
#     Nombre del archivo (.jpg)                                  Patrón global  \
# 0                ISIC_0000000                               Reticular difuso
# 1                ISIC_0000001                               Reticular difuso
# 2                ISIC_0000002           Mixto (mezcla dos de los anteriores)
# 3                ISIC_0000004  Multicomponente ( mezcla 3 o más anteriores )
# 4                ISIC_0000006                            Reticular parcheado
# ..                        ...                                            ...
# 895              ISIC_0011393                                     Indefinido
# 896              ISIC_0011397                                     Indefinido
# 897              ISIC_0011398                               Reticular difuso
# 898              ISIC_0011400                                     Indefinido
# 899              ISIC_0011402                               Reticular difuso
#
#        Retículo pigmentado Retículo negativo Puntos/Glóbulos pequeños  \
# 0    Sí, claro y dominante                No                Sí, sutil
# 1    Sí, claro y dominante                No                Sí, sutil
# 2    Sí, claro y dominante                No                       No
# 3                Sí, sutil                No                       No
# 4    Sí, claro y dominante                No                       No
# ..                     ...               ...                      ...
# 895                     No                No                       No
# 896                     No                No                Sí, claro
# 897  Sí, claro y dominante                No                Sí, sutil
# 898                     No                No                Sí, sutil
# 899  Sí, claro y dominante                No                       No
#
#     Glóbulos grandes/Empedrado Glóbulos periféricos Proyecciones periféricas  \
# 0                           No                   No                Sí, sutil
# 1                           No                   No                       No
# 2                           No                   No                       No
# 3                           No                   No                       No
# 4                           No                   No                       No
# ..                         ...                  ...                      ...
# 895                  Sí, sutil                   No                       No
# 896                         No            Sí, sutil                       No
# 897                         No                   No                       No
# 898                         No                   No                Sí, sutil
# 899                         No                   No                       No
#
#     Área homogénea sin vasos Área homogénea con vasos        Área indefinida  \
# 0                         No                       No              Sí, sutil
# 1                  Sí, sutil                       No                     No
# 2      Sí, claro y dominante                       No              Sí, claro
# 3      Sí, claro y dominante    Sí, claro y dominante  Sí, claro y dominante
# 4                         No                       No                     No
# ..                       ...                      ...                    ...
# 895                       No                       No                     No
# 896                       No                       No                     No
# 897                       No                       No                     No
# 898                       No                       No                     No
# 899                       No                       No                     No
#
#     Regresión gris Regresión blanca Velo azul blanquecino Crisálidas  \
# 0               No               No                    No         No
# 1               No               No                    No         No
# 2        Sí, sutil               No                    No         No
# 3        Sí, claro        Sí, claro             Sí, sutil         No
# 4               No               No                    No         No
# ..             ...              ...                   ...        ...
# 895             No               No                    No         No
# 896      Sí, claro               No                    No         No
# 897             No               No                    No         No
# 898             No               No                    No         No
# 899             No               No                    No         No
#
#     Etiqueta binaria
# 0             benign
# 1             benign
# 2          malignant
# 3          malignant
# 4             benign
# ..               ...
# 895           benign
# 896           benign
# 897           benign
# 898           benign
# 899           benign
#
# [900 rows x 16 columns]

# %%
df_melanoma
# Out:
#      Nº de imagen Identificador de la lesión Nombre del archivo (.jpg)  \
# 0               1                         L1                     1.jpg
# 1               2                         L2                     2.jpg
# 2               3                         L3                     3.jpg
# 3               4                         L4                     4.jpg
# 4               5                         L5                     5.jpg
# ..            ...                        ...                       ...
# 495           496                       L496                   496.jpg
# 496           497                        497                   497.jpg
# 497           498                       L498                   498.jpg
# 498           499                        499                   499.jpg
# 499           500                       L500                   500.jpg
#
#     Centro de Procedencia Equipo de dermatoscopia Tipo de Luz   Sexo  Edad  \
# 0                     IMO              Molemax-II  Polarizada  Varón    28
# 1                     IMO              Molemax-II  Polarizada  Varón    44
# 2                     IMO              Molemax-II  Polarizada  Mujer    35
# 3                     IMO              Molemax-II  Polarizada  Varón    34
# 4                     IMO              Molemax-II  Polarizada  Varón    38
# ..                    ...                     ...         ...    ...   ...
# 495                   IMO              Molemax-II  Polarizada  Mujer    38
# 496                   IMO          Dermlite Photo  Polarizada  Mujer    49
# 497                   IMO          Dermlite Photo  Polarizada  Mujer    59
# 498                   IMO          Dermlite Photo  Polarizada  Varón    35
# 499                   IMO              Molemax-II  Polarizada  Varón    44
#
#                 Localización Silueta general de la lesión  ...  \
# 0                    Espalda                        Plana  ...
# 1                    Espalda                        Plana  ...
# 2    Tronco antero - lateral                        Plana  ...
# 3                    Espalda                        Plana  ...
# 4                    Espalda                        Plana  ...
# ..                       ...                          ...  ...
# 495  Tronco antero - lateral                        Plana  ...
# 496      Miembros superiores                        Plana  ...
# 497                  Espalda                        Plana  ...
# 498      Miembros inferiores                        Plana  ...
# 499                  Espalda        Aplanada sobreelevada  ...
#
#     Glóbulos grandes/Empedrado Glóbulos periféricos  Proyecciones periféricas  \
# 0                           No                   No                        No
# 1                           No                   No                        No
# 2                           No            Sí, sutil                        No
# 3                           No                   No                        No
# 4                          NaN            Sí, sutil                        No
# ..                         ...                  ...                       ...
# 495                         No                   No                        No
# 496                         No                   No                        No
# 497                         No            Sí, claro                        No
# 498                         No                   No                 Sí, sutil
# 499                  Sí, claro            Sí, sutil                        No
#
#     Área homogénea sin vasos Área homogénea con vasos        Área indefinida  \
# 0                  Sí, sutil                       No                     No
# 1                  Sí, sutil                       No                     No
# 2      Sí, claro y dominante                       No                     No
# 3                         No                       No                     No
# 4                         No                       No              Sí, sutil
# ..                       ...                      ...                    ...
# 495                Sí, sutil                       No              Sí, claro
# 496                       No                       No                     No
# 497                       No                       No              Sí, sutil
# 498                       No                       No                     No
# 499                       No                       No  Sí, claro y dominante
#
#     Regresión gris Regresión blanca Velo azul blanquecino Crisálidas
# 0               No               No                    No         No
# 1               No               No                    No         No
# 2               No               No                    No         No
# 3               No               No                    No         No
# 4               No               No                    No         No
# ..             ...              ...                   ...        ...
# 495             No               No                    No         No
# 496      Sí, sutil        Sí, claro                    No         No
# 497             No               No                    No         No
# 498      Sí, sutil               No                    No         No
# 499             No               No                    No         No
#
# [500 rows x 33 columns]

# %%
df_melanoma.columns
# Out:
# Index(['Nº de imagen', 'Identificador de la lesión',
#        'Nombre del archivo (.jpg)', 'Centro de Procedencia',
#        'Equipo de dermatoscopia', 'Tipo de Luz', 'Sexo', 'Edad',
#        'Localización', 'Silueta general de la lesión',
#        'Diagnóstico histológico', 'Nivel de displasia', 'Espesor',
#        'Nivel de Clark', 'Impresión diagnóstica', 'Dificultad diagnóstica',
#        'Extirpación', 'Patrón global', 'Patrón globular periférico',
#        'Simetría', 'Retículo pigmentado', 'Retículo negativo',
#        'Puntos/Glóbulos pequeños', 'Glóbulos grandes/Empedrado',
#        'Glóbulos periféricos', 'Proyecciones periféricas',
#        'Área homogénea sin vasos', 'Área homogénea con vasos',
#        'Área indefinida', 'Regresión gris', 'Regresión blanca',
#        'Velo azul blanquecino', 'Crisálidas'],
#       dtype='object')

# %%
# We only need one identifier for the images
df_melanoma.drop(columns=['Nº de imagen', 'Identificador de la lesión'], inplace=True)

# %%
df_melanoma
# Out:
#     Nombre del archivo (.jpg) Centro de Procedencia Equipo de dermatoscopia  \
# 0                       1.jpg                   IMO              Molemax-II
# 1                       2.jpg                   IMO              Molemax-II
# 2                       3.jpg                   IMO              Molemax-II
# 3                       4.jpg                   IMO              Molemax-II
# 4                       5.jpg                   IMO              Molemax-II
# ..                        ...                   ...                     ...
# 495                   496.jpg                   IMO              Molemax-II
# 496                   497.jpg                   IMO          Dermlite Photo
# 497                   498.jpg                   IMO          Dermlite Photo
# 498                   499.jpg                   IMO          Dermlite Photo
# 499                   500.jpg                   IMO              Molemax-II
#
#     Tipo de Luz   Sexo  Edad             Localización  \
# 0    Polarizada  Varón    28                  Espalda
# 1    Polarizada  Varón    44                  Espalda
# 2    Polarizada  Mujer    35  Tronco antero - lateral
# 3    Polarizada  Varón    34                  Espalda
# 4    Polarizada  Varón    38                  Espalda
# ..          ...    ...   ...                      ...
# 495  Polarizada  Mujer    38  Tronco antero - lateral
# 496  Polarizada  Mujer    49      Miembros superiores
# 497  Polarizada  Mujer    59                  Espalda
# 498  Polarizada  Varón    35      Miembros inferiores
# 499  Polarizada  Varón    44                  Espalda
#
#     Silueta general de la lesión          Diagnóstico histológico  \
# 0                          Plana  Lunar no atípico y estable (L)
# 1                          Plana  Lunar no atípico y estable (L)
# 2                          Plana  Lunar no atípico y estable (L)
# 3                          Plana  Lunar no atípico y estable (L)
# 4                          Plana  Lunar no atípico y estable (L)
# ..                           ...                              ...
# 495                        Plana           Melanoma in situ (MIS)
# 496                        Plana           Melanoma in situ (MIS)
# 497                        Plana           Melanoma in situ (MIS)
# 498                        Plana           Melanoma in situ (MIS)
# 499        Aplanada sobreelevada           Melanoma in situ (MIS)
#
#     Nivel de displasia  ...  Glóbulos grandes/Empedrado Glóbulos periféricos  \
# 0            No aplica  ...                          No                   No
# 1            No aplica  ...                          No                   No
# 2            No aplica  ...                          No            Sí, sutil
# 3            No aplica  ...                          No                   No
# 4            No aplica  ...                         NaN            Sí, sutil
# ..                 ...  ...                         ...                  ...
# 495          No aplica  ...                          No                   No
# 496          No aplica  ...                          No                   No
# 497          No aplica  ...                          No            Sí, claro
# 498          No aplica  ...                          No                   No
# 499          No aplica  ...                   Sí, claro            Sí, sutil
#
#     Proyecciones periféricas Área homogénea sin vasos  \
# 0                         No                Sí, sutil
# 1                         No                Sí, sutil
# 2                         No    Sí, claro y dominante
# 3                         No                       No
# 4                         No                       No
# ..                       ...                      ...
# 495                       No                Sí, sutil
# 496                       No                       No
# 497                       No                       No
# 498                Sí, sutil                       No
# 499                       No                       No
#
#     Área homogénea con vasos        Área indefinida Regresión gris  \
# 0                         No                     No             No
# 1                         No                     No             No
# 2                         No                     No             No
# 3                         No                     No             No
# 4                         No              Sí, sutil             No
# ..                       ...                    ...            ...
# 495                       No              Sí, claro             No
# 496                       No                     No      Sí, sutil
# 497                       No              Sí, sutil             No
# 498                       No                     No      Sí, sutil
# 499                       No  Sí, claro y dominante             No
#
#     Regresión blanca Velo azul blanquecino Crisálidas
# 0                 No                    No         No
# 1                 No                    No         No
# 2                 No                    No         No
# 3                 No                    No         No
# 4                 No                    No         No
# ..               ...                   ...        ...
# 495               No                    No         No
# 496        Sí, claro                    No         No
# 497               No                    No         No
# 498               No                    No         No
# 499               No                    No         No
#
# [500 rows x 31 columns]

# %%
# Check for NAs/missing values
df_fusion.isna().sum()
# Out:
# Nombre del archivo (.jpg)     0
# Patrón global                 0
# Retículo pigmentado           0
# Retículo negativo             0
# Puntos/Glóbulos pequeños      0
# Glóbulos grandes/Empedrado    0
# Glóbulos periféricos          0
# Proyecciones periféricas      0
# Área homogénea sin vasos      0
# Área homogénea con vasos      0
# Área indefinida               0
# Regresión gris                0
# Regresión blanca              0
# Velo azul blanquecino         0
# Crisálidas                    0
# Etiqueta binaria              0
# dtype: int64

# %%
df_melanoma.isna().sum()
# Out:
# Nombre del archivo (.jpg)         0
# Centro de Procedencia             0
# Equipo de dermatoscopia           0
# Tipo de Luz                       0
# Sexo                              0
# Edad                              0
# Localización                      0
# Silueta general de la lesión      0
# Diagnóstico histológico           0
# Nivel de displasia                9
# Espesor                         405
# Nivel de Clark                  405
# Impresión diagnóstica             0
# Dificultad diagnóstica            0
# Extirpación                       0
# Patrón global                     0
# Patrón globular periférico        3
# Simetría                         13
# Retículo pigmentado               0
# Retículo negativo                 0
# Puntos/Glóbulos pequeños          0
# Glóbulos grandes/Empedrado        3
# Glóbulos periféricos              2
# Proyecciones periféricas          0
# Área homogénea sin vasos          0
# Área homogénea con vasos          0
# Área indefinida                   0
# Regresión gris                    0
# Regresión blanca                  0
# Velo azul blanquecino             0
# Crisálidas                        3
# dtype: int64

# %% [markdown]
# ## Dataframe translation

# %%
# # Function to translate values from Spanish to English
# def translate_value(val):
#     if isinstance(val, str):
#         translation = Translator(from_lang='es', to_lang='en').translate(val)
#     else:
#         translation = val
#     return translation

# %%
# # Function to translate different categories
# def translate_categories(categories, fromLang = 'es', toLang='en'):
#     translator = Translator(from_lang = fromLang, to_lang = toLang)
#     translations = [translator.translate(category) for category in categories]
#     return dict(zip(categories, translations))

# %%
# # Function to translate column names and values in the entire DataFrame
# def translate_dataframe(df, fromLang = 'es', toLang='en'):
    
#     # Translate column names
#     df.columns = [Translator(from_lang=fromLang, to_lang = toLang).translate(col) for col in df.columns]

#     translations = {}
#     for col in df.columns:
#         unique_categories = df[col].unique()
#         translations[col] = translate_categories(unique_categories)

#     # Map the translations back to the DataFrame
#     for col in df.columns:
#         df[col] = df[col].map(translations[col]).fillna(df[col])

#     return df

# %%
# df_fusion = translate_dataframe(df_fusion)
# df_fusion

# %%
# df_melanoma.columns = [translate_value(col) for col in df_melanoma.columns]
# df_melanoma.columns

# %%
# df_melanoma = df_melanoma.applymap(translate_value)

# %%
df_melanoma.columns
# Out:
# Index(['Nombre del archivo (.jpg)', 'Centro de Procedencia',
#        'Equipo de dermatoscopia', 'Tipo de Luz', 'Sexo', 'Edad',
#        'Localización', 'Silueta general de la lesión',
#        'Diagnóstico histológico', 'Nivel de displasia', 'Espesor',
#        'Nivel de Clark', 'Impresión diagnóstica', 'Dificultad diagnóstica',
#        'Extirpación', 'Patrón global', 'Patrón globular periférico',
#        'Simetría', 'Retículo pigmentado', 'Retículo negativo',
#        'Puntos/Glóbulos pequeños', 'Glóbulos grandes/Empedrado',
#        'Glóbulos periféricos', 'Proyecciones periféricas',
#        'Área homogénea sin vasos', 'Área homogénea con vasos',
#        'Área indefinida', 'Regresión gris', 'Regresión blanca',
#        'Velo azul blanquecino', 'Crisálidas'],
#       dtype='object')

# %%
melanomaData_map = {

    'Nombre del archivo (.jpg)': {
        'colName': 'File name (.jpg)',
        'values': {}
    },
    
    'Centro de Procedencia': {
        'colName': 'Center',
        'values': {
            'IMO': 'IMO',
            'CDI': 'CDI',
            'CR': 'CR'
        }
    },
    'Equipo de dermatoscopia': {
        'colName': 'Equipment',
        'values': {
            'Molemax-II': 'Molemax-II',
            'Molemax HD': 'Molemax HD',
            'Fotofinder': 'Fotofinder',
            'Heynedermaphot': 'Heynedermaphot',
            'Dermlite Photo': 'Dermlite Photo',
            'Dermlite DL3': 'Dermlite DL3'
        }
    },
    'Tipo de Luz': {
        'colName': 'Light',
        'values': {
            'Polarizada': 'Polarized',
            'No polarizada': 'Non-polarized'
        }
    },
    'Sexo': {
        'colName': 'Gender',
        'values': {
            'Varón': 'Male',
            'Mujer': 'Female'
        }
    },
    'Edad': {
        'colName': 'Age',
        'values': {}
    },
    'Localización': {
        'colName': 'Location',
        'values': {
            'Cuello': 'Neck',
            'Tronco antero - lateral': 'Anterolateral Trunk',
            'Espalda': 'Back',
            'Miembros superiores': 'Upper limbs',
            'Miembros inferiores': 'Lower limbs'
        }
    },
    'Silueta general de la lesión': {
        'colName': 'General Silhouette',
        'values': {
            'Plana': 'Flat',
            'Aplanada sobreelevada': 'Flattened Elevated',
            'Exofítica': 'Exophytic'
        }
    },
    'Diagnóstico histológico': {
        'colName': 'Histology Diagnostic',
        'values': {
            'Melanoma in situ (MIS)': 'Melanoma in situ (MIS)',
            'Melanoma de extensión superficial (MES)': 'Superficial Spreading Melanoma (SSM)',
            'Melanoma nodular (MN)': 'Nodular Melanoma (NM)',
            'Melanoma sobre nevo congénito (MsNCg)': 'Melanoma on Congenital Nevus (MCN)',
            'Melanoma spitzoide/Nevo de Spitz maligno (MS)': 'Spitzoid Melanoma/Malignant Spitz Nevus (MSN)',
            'Nevo azul maligno (NAM)': 'Malignant Blue Nevus (MBN)',
            'Nevo de Spitz (NS)': 'Spitz Nevus (SN)',
            'Nevo de Reed (NR)': 'Reed Nevus (NR)',
            'Nevo melanocítico displásico (NMD)': 'Dysplastic Melanocytic Nevus (DMN)',
            'Nevo melanocítico lentiginoso (NML)': 'Lentiginous Melanocytic Nevus (LMN)',
            'Nevo melanocítico congénito (NMCg)': 'Congenital Melanocytic Nevus (CMN)',
            'Nevo melanocítico juntural (NMJ)': 'Junctional Melanocytic Nevus (JMN)',
            'Nevo melanocítico compuesto (NMC)': 'Compound Melanocytic Nevus (CMN)',
            'Nevo melanocítico intradérmico (NMI)': 'Intradermal Melanocytic Nevus (IMN)',
            'Nevo azul (NA)': 'Blue Nevus (BN)',
            'Lunar no atípico y estable (L)': 'Non-atypical Stable Mole (M)'
        }
    },
    'Nivel de displasia': {
        'colName': 'Dysplasia',
        'values': {
            'No aplica': 'Not Applicable',
            'No disponible': 'Not Available',
            'Severa': 'Severe'
        }
    },
    'Espesor': {
        'colName': 'Thickness',
        'values': {}
    },
    'Nivel de Clark': {
        'colName': 'Clark Level',
        'values': {
            'I (melanoma in situ)': 'I (melanoma in situ)',
            'II': 'II',
            'III': 'III',
            'IV': 'IV',
            'V': 'V'
        }
    },
    'Impresión diagnóstica': {
        'colName': 'Diagnostic Impression',
        'values': {
            'Melanoma': 'Melanoma',
            'Descartar melanoma': 'Exclude Melanoma',
            'Lunar de Spitz/Reed': 'Spitz/Reed Nevus',
            'Lunar Atípico': 'Atypical Mole',
            'Lunar no atípico': 'Non-atypical Mole'
        }
    },
    'Dificultad diagnóstica': {
        'colName': 'Diagnostic Difficulty',
        'values': {
            'Baja': 'Low',
            'Media': 'Medium',
            'Alta': 'High'
        }
    },
    'Extirpación': {
        'colName': 'Excision',
        'values': {
            'No extirpado': 'Not Excised',
            'Primera consulta': 'First Consultation',
            'Seguimento, sin dermatoscopia previa': 'Follow-up, without previous dermoscopy',
            'Seguimiento con dermatoscopia previa, por cambios': 'Follow-up with previous dermoscopy, due to changes',
            'Seguimiento con dermatoscipa previa, por síntomas': 'Follow-up with previous dermoscopy, due to symptoms'
            
        }
    },
    'Patrón global': {
        'colName': 'Global Pattern',
        'values': {
            'Reticular difuso': 'Diffuse Reticular',
            'Reticular parcheado': 'Patchy Reticular',
            'Globular': 'Globular',
            'Empedrado': 'Cobblestone',
            'Homogéneo': 'Homogeneous',
            'Mixto (mezcla dos de los anteriores)': 'Mixed (mix of two of the above)',
            'Multicomponente ( mezcla 3 o más anteriores )': 'Multicomponent (mix of 3 or more above)',
            'Indefinido': 'Undefined'
        }
    },
    'Patrón globular periférico': {
        'colName': 'Peripheral Globular Pattern',
        'values': {
            'Ausente': 'Absent',
            'Regular convencional': 'Regular Conventional',
            'Regular en estallido': 'Regular Bursting',
            'Irregular convencional': 'Irregular Conventional',
            'Irregular en estallido': 'Irregular Bursting',
            'Focal convencional': 'Focal Conventional',
            'Focal en estallido': 'Focal Bursting'
        }
    },
    'Simetría': {
        'colName': 'Symmetry',
        'values': {
            'Simétrico': 'Symmetric',
            'Asimétrico en un eje': 'Asymmetric on one axis',
            'Asimétrico en dos ejes': 'Asymmetric on two axes'
        }
    },
    'Retículo pigmentado': {
        'colName': 'Pigmented Reticulum',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Retículo negativo': {
        'colName': 'Negative Reticulum',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Puntos/Glóbulos pequeños': {
        'colName': 'Small Dots/Globules',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Glóbulos grandes/Empedrado': {
        'colName': 'Large Globules/Cobblestone',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Glóbulos periféricos': {
        'colName': 'Peripheral Globules',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Proyecciones periféricas': {
        'colName': 'Peripheral Projections',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Área homogénea sin vasos': {
        'colName': 'Homogeneous Area without Vessels',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Área homogénea con vasos': {
        'colName': 'Homogeneous Area with Vessels',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Área indefinida': {
        'colName': 'Undefined Area',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Regresión gris': {
        'colName': 'Gray Regression',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Regresión blanca': {
        'colName': 'White Regression',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Velo azul blanquecino': {
        'colName': 'Whitish Blue Veil',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    },
    'Crisálidas': {
        'colName': 'Chrysalis',
        'values': {
            'No': 'No',
            'Sí, sutil': 'Yes, subtle',
            'Sí, claro': 'Yes, clear',
            'Sí, claro y dominante': 'Yes, clear and dominant'
        }
    }
}

# %%
# Create a copy of the dataframe
df_melanoma_mapped = df_melanoma.copy()

# Columns to map
columns_to_map = df_melanoma.columns

# Iterate through all the columns
for col in columns_to_map:

    # Apply the mapping for the variable name using the dictionary
    newColName = melanomaData_map[col]['colName']

    # Clean all trailing blank spaces from strings before mapping
    # Example: '  Lunar no atípico y estable (L)   ' -> 'Lunar no atípico y estable (L)'
    if df_melanoma_mapped[col].dtype == 'O':
        df_melanoma_mapped[col] = df_melanoma_mapped[col].str.strip()

    # Avoid NaN generation for numerical variables or IDs without translation
    if melanomaData_map[col]['values']:
        df_melanoma_mapped[newColName] = df_melanoma_mapped[col].map(melanomaData_map[col]['values'])
    else:
        df_melanoma_mapped[newColName] = df_melanoma[col]

    # Drop the columns in Spanish
    df_melanoma_mapped.drop(columns=col, inplace=True)

# %%
df_melanoma_mapped.columns
# Out:
# Index(['File name (.jpg)', 'Center', 'Equipment', 'Light', 'Gender', 'Age',
#        'Location', 'General Silhouette', 'Histology Diagnostic', 'Dysplasia',
#        'Thickness', 'Clark Level', 'Diagnostic Impression',
#        'Diagnostic Difficulty', 'Excision', 'Global Pattern',
#        'Peripheral Globular Pattern', 'Symmetry', 'Pigmented Reticulum',
#        'Negative Reticulum', 'Small Dots/Globules',
#        'Large Globules/Cobblestone', 'Peripheral Globules',
#        'Peripheral Projections', 'Homogeneous Area without Vessels',
#        'Homogeneous Area with Vessels', 'Undefined Area', 'Gray Regression',
#        'White Regression', 'Whitish Blue Veil', 'Chrysalis'],
#       dtype='object')

# %%
na_sum = df_melanoma_mapped.isna().sum()
na_sum
# Out:
# File name (.jpg)                      0
# Center                                0
# Equipment                             0
# Light                                 0
# Gender                                0
# Age                                   0
# Location                              0
# General Silhouette                    0
# Histology Diagnostic                  0
# Dysplasia                             9
# Thickness                           405
# Clark Level                         405
# Diagnostic Impression                 0
# Diagnostic Difficulty                 0
# Excision                              0
# Global Pattern                        0
# Peripheral Globular Pattern           3
# Symmetry                             13
# Pigmented Reticulum                   0
# Negative Reticulum                    0
# Small Dots/Globules                   0
# Large Globules/Cobblestone            3
# Peripheral Globules                   2
# Peripheral Projections                0
# Homogeneous Area without Vessels      0
# Homogeneous Area with Vessels         0
# Undefined Area                        0
# Gray Regression                       0
# White Regression                      0
# Whitish Blue Veil                     0
# Chrysalis                             3
# dtype: int64

# %%
# Store those columns with NAs
columns_with_na = na_sum[na_sum > 0].index.to_list()
columns_with_na
# Out:
# ['Dysplasia',
#  'Thickness',
#  'Clark Level',
#  'Peripheral Globular Pattern',
#  'Symmetry',
#  'Large Globules/Cobblestone',
#  'Peripheral Globules',
#  'Chrysalis']

# %%
# Compare the amount of NAs in those columns to check if there has been NA injection
na_sum_original_melanoma = df_melanoma.isna().sum().values
na_sum_mapped_melanoma = df_melanoma_mapped.isna().sum().values

# %%
na_sum_comparison = pd.DataFrame([na_sum_original_melanoma, na_sum_mapped_melanoma], index=['df_melanoma', 'df_melanoma_mapped']).T
na_sum_comparison.index = df_melanoma_mapped.columns

# %%
na_sum_comparison
# Out:
#                                   df_melanoma  df_melanoma_mapped
# File name (.jpg)                            0                   0
# Center                                      0                   0
# Equipment                                   0                   0
# Light                                       0                   0
# Gender                                      0                   0
# Age                                         0                   0
# Location                                    0                   0
# General Silhouette                          0                   0
# Histology Diagnostic                        0                   0
# Dysplasia                                   9                   9
# Thickness                                 405                 405
# Clark Level                               405                 405
# Diagnostic Impression                       0                   0
# Diagnostic Difficulty                       0                   0
# Excision                                    0                   0
# Global Pattern                              0                   0
# Peripheral Globular Pattern                 3                   3
# Symmetry                                   13                  13
# Pigmented Reticulum                         0                   0
# Negative Reticulum                          0                   0
# Small Dots/Globules                         0                   0
# Large Globules/Cobblestone                  3                   3
# Peripheral Globules                         2                   2
# Peripheral Projections                      0                   0
# Homogeneous Area without Vessels            0                   0
# Homogeneous Area with Vessels               0                   0
# Undefined Area                              0                   0
# Gray Regression                             0                   0
# White Regression                            0                   0
# Whitish Blue Veil                           0                   0
# Chrysalis                                   3                   3

# %%
excision_missing_index = df_melanoma_mapped[df_melanoma_mapped['Excision'].isna()].index
global_pattern_missing_index = df_melanoma_mapped[df_melanoma_mapped['Global Pattern'].isna()].index

# %%
df_melanoma["Extirpación"][excision_missing_index]
# Out:
# Series([], Name: Extirpación, dtype: object)

# %%
df_melanoma["Patrón global"][global_pattern_missing_index]
# Out:
# Series([], Name: Patrón global, dtype: object)

# %%
df_melanoma_mapped
# Out:
#     File name (.jpg) Center       Equipment      Light  Gender  Age  \
# 0              1.jpg    IMO      Molemax-II  Polarized    Male   28
# 1              2.jpg    IMO      Molemax-II  Polarized    Male   44
# 2              3.jpg    IMO      Molemax-II  Polarized  Female   35
# 3              4.jpg    IMO      Molemax-II  Polarized    Male   34
# 4              5.jpg    IMO      Molemax-II  Polarized    Male   38
# ..               ...    ...             ...        ...     ...  ...
# 495          496.jpg    IMO      Molemax-II  Polarized  Female   38
# 496          497.jpg    IMO  Dermlite Photo  Polarized  Female   49
# 497          498.jpg    IMO  Dermlite Photo  Polarized  Female   59
# 498          499.jpg    IMO  Dermlite Photo  Polarized    Male   35
# 499          500.jpg    IMO      Molemax-II  Polarized    Male   44
#
#                 Location  General Silhouette          Histology Diagnostic  \
# 0                   Back                Flat  Non-atypical Stable Mole (M)
# 1                   Back                Flat  Non-atypical Stable Mole (M)
# 2    Anterolateral Trunk                Flat  Non-atypical Stable Mole (M)
# 3                   Back                Flat  Non-atypical Stable Mole (M)
# 4                   Back                Flat  Non-atypical Stable Mole (M)
# ..                   ...                 ...                           ...
# 495  Anterolateral Trunk                Flat        Melanoma in situ (MIS)
# 496          Upper limbs                Flat        Melanoma in situ (MIS)
# 497                 Back                Flat        Melanoma in situ (MIS)
# 498          Lower limbs                Flat        Melanoma in situ (MIS)
# 499                 Back  Flattened Elevated        Melanoma in situ (MIS)
#
#           Dysplasia  ...  Large Globules/Cobblestone Peripheral Globules  \
# 0    Not Applicable  ...                          No                  No
# 1    Not Applicable  ...                          No                  No
# 2    Not Applicable  ...                          No         Yes, subtle
# 3    Not Applicable  ...                          No                  No
# 4    Not Applicable  ...                         NaN         Yes, subtle
# ..              ...  ...                         ...                 ...
# 495  Not Applicable  ...                          No                  No
# 496  Not Applicable  ...                          No                  No
# 497  Not Applicable  ...                          No          Yes, clear
# 498  Not Applicable  ...                          No                  No
# 499  Not Applicable  ...                  Yes, clear         Yes, subtle
#
#     Peripheral Projections Homogeneous Area without Vessels  \
# 0                       No                      Yes, subtle
# 1                       No                      Yes, subtle
# 2                       No          Yes, clear and dominant
# 3                       No                               No
# 4                       No                               No
# ..                     ...                              ...
# 495                     No                      Yes, subtle
# 496                     No                               No
# 497                     No                               No
# 498            Yes, subtle                               No
# 499                     No                               No
#
#     Homogeneous Area with Vessels           Undefined Area Gray Regression  \
# 0                              No                       No              No
# 1                              No                       No              No
# 2                              No                       No              No
# 3                              No                       No              No
# 4                              No              Yes, subtle              No
# ..                            ...                      ...             ...
# 495                            No               Yes, clear              No
# 496                            No                       No     Yes, subtle
# 497                            No              Yes, subtle              No
# 498                            No                       No     Yes, subtle
# 499                            No  Yes, clear and dominant              No
#
#     White Regression Whitish Blue Veil Chrysalis
# 0                 No                No        No
# 1                 No                No        No
# 2                 No                No        No
# 3                 No                No        No
# 4                 No                No        No
# ..               ...               ...       ...
# 495               No                No        No
# 496       Yes, clear                No        No
# 497               No                No        No
# 498               No                No        No
# 499               No                No        No
#
# [500 rows x 31 columns]

# %%
df_melanoma_mapped.drop(columns={'Thickness', 'Clark Level'}, inplace=True)

# %%
df_melanoma_mapped.columns
# Out:
# Index(['File name (.jpg)', 'Center', 'Equipment', 'Light', 'Gender', 'Age',
#        'Location', 'General Silhouette', 'Histology Diagnostic', 'Dysplasia',
#        'Diagnostic Impression', 'Diagnostic Difficulty', 'Excision',
#        'Global Pattern', 'Peripheral Globular Pattern', 'Symmetry',
#        'Pigmented Reticulum', 'Negative Reticulum', 'Small Dots/Globules',
#        'Large Globules/Cobblestone', 'Peripheral Globules',
#        'Peripheral Projections', 'Homogeneous Area without Vessels',
#        'Homogeneous Area with Vessels', 'Undefined Area', 'Gray Regression',
#        'White Regression', 'Whitish Blue Veil', 'Chrysalis'],
#       dtype='object')

# %%
df_melanoma_mapped.to_csv('../../data/processed/df_melanoma_clean.csv', index=False)
